# %%
import cv2
import itertools
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# ### Load Trained YOLO Models

# %%
# ball_model = YOLO("models/ball_best_v8_30e.pt")
table_model = YOLO("models/table_yolo_v11_20e.pt")
# table_model = YOLO("models/table_yolo_v11_10e.pt")
ball_model = YOLO("models/ball_best_v11_15e.pt")

# %%
def correct_frame_orientation(frame):
    h, w = frame.shape[:2]
    if h > w:
        return frame  # already portrait
    else:
        return cv2.rotate(frame, cv2.ROTATE_90_CLOCKWISE)
    
def order_points_from_short_sides_adaptive(pts):
    """
    Hybrid version:
    - If the table is clearly vertical (height >> width), use top/bottom quadrant logic.
    - Else, use the robust short-side vector sorting.
    Returns corners in TL, TR, BR, BL order.
    """
    pts = np.array(pts, dtype=np.float32)

    # Step 1: Compute bounding box
    min_x, max_x = np.min(pts[:, 0]), np.max(pts[:, 0])
    min_y, max_y = np.min(pts[:, 1]), np.max(pts[:, 1])
    width = max_x - min_x
    height = max_y - min_y

    if height > 1.2 * width:
        # ⚠️ Table is vertical
        center_y = (min_y + max_y) / 2
        upper = []
        lower = []
        for pt in pts:
            if pt[1] < center_y:
                upper.append(pt)
            else:
                lower.append(pt)

        if len(upper) != 2 or len(lower) != 2:
            raise ValueError("Unexpected corner distribution in vertical mode.")

        upper = sorted(upper, key=lambda p: p[0])  # left to right
        lower = sorted(lower, key=lambda p: p[0])  # left to right

        tl, tr = upper
        bl, br = lower
        return np.array([tl, tr, br, bl], dtype=np.float32)

    else:
        # ✅ Use the reliable short-side vector-based ordering
        dists = []
        for i, j in itertools.combinations(range(4), 2):
            d = np.linalg.norm(pts[i] - pts[j])
            dists.append((d, i, j))
        dists.sort()
        (_, i1, j1), (_, i2, j2) = dists[:2]

        vec1 = pts[j1] - pts[i1]
        vec2 = pts[j2] - pts[i2]
        if vec1[0] > 0: vec1 = -vec1
        if vec2[0] > 0: vec2 = -vec2
        x1, x2 = vec1[0], vec2[0]

        if x1 < x2:
            left_pair = [pts[i1], pts[j1]]
            right_pair = [pts[i2], pts[j2]]
        else:
            left_pair = [pts[i2], pts[j2]]
            right_pair = [pts[i1], pts[j1]]

        left_pair = sorted(left_pair, key=lambda p: p[1])
        right_pair = sorted(right_pair, key=lambda p: p[1])

        tl, bl = left_pair
        tr, br = right_pair
        return np.array([tl, tr, br, bl], dtype=np.float32)
    
def order_points_from_short_sides(pts):
    """
    Orders 4 corner points of a rectangle into: [top-left, top-right, bottom-right, bottom-left].
    """
    pts = np.asarray(pts, dtype=np.float32)
    if pts.shape != (4, 2):
        raise ValueError("pts must be shape (4, 2)")

    # Compute all pairwise distances, store pairs
    pairs = list(itertools.combinations(range(4), 2))
    dists = np.linalg.norm(pts[pairs][:, 0] - pts[pairs][:, 1], axis=1)
    idx = np.argsort(dists)[:2]
    short_pairs = [pairs[i] for i in idx]

    # Gather unique indices of short side points (should be 3)
    short_idxs = list(set(i for pair in short_pairs for i in pair))
    if len(short_idxs) != 3:
        raise ValueError("Could not determine two distinct short sides.")

    # Count occurrences to find the shared (corner) index
    counts = {i: sum(i in pair for pair in short_pairs) for i in short_idxs}
    shared = [i for i, c in counts.items() if c == 2][0]
    neighbors = [i for i in short_idxs if i != shared]

    v1, v2 = pts[neighbors[0]] - pts[shared], pts[neighbors[1]] - pts[shared]
    cross = np.cross(v1, v2)
    if cross > 0:
        tl, tr, bl = pts[shared], pts[neighbors[0]], pts[neighbors[1]]
    else:
        tl, tr, bl = pts[shared], pts[neighbors[1]], pts[neighbors[0]]

    br_idx = next(i for i in range(4) if i not in [shared] + neighbors)
    br = pts[br_idx]

    return np.array([tl, tr, br, bl], dtype=np.float32)

def order_points_clockwise(pts):
    pts = np.array(pts, dtype="float32")
    center = np.mean(pts, axis=0)

    def angle(p):
        return np.arctan2(p[1] - center[1], p[0] - center[0])

    pts_sorted = sorted(pts, key=angle)
    return np.array(pts_sorted, dtype="float32")

def order_points_stable(pts):
    pts = np.array(pts, dtype="float32")
    s = pts.sum(axis=1)
    diff = np.diff(pts, axis=1)

    return np.array([
        pts[np.argmin(s)],      # top-left
        pts[np.argmin(diff)],   # top-right
        pts[np.argmax(s)],      # bottom-right
        pts[np.argmax(diff)]    # bottom-left
    ], dtype="float32")

# %% [markdown]
# ### Class list

# %%
ball_label_to_name = {
    0: "cue_ball",
    1: "8_ball",
    2: "stripe",
    3: "solid"
}

# %% [markdown]
# ### Mapping a Video (New Method)

# %%
def detect_table_and_map_balls_from_video(video_path, output_path='video_output/', max_frames=1000):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return

    output_path +=  "out_" + video_path.split("/")[-1]

    # Video properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_to_process = min(total_frames, max_frames)

    # Set output video writer
    combined_width = width * 2
    combined_height = height
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (combined_width, combined_height))

    homography, dst_width, dst_height, mask_resized = None, None, None, None
    dst_width = 400
    dst_height = 800
    table_set = False
    frame_idx = 0

    while frame_idx < frames_to_process:
            ret, frame = cap.read()
            if not ret:
                break
            frame = correct_frame_orientation(frame)

            # Update width/height AFTER orientation fix
            height, width = frame.shape[:2]

            # Re-initialize VideoWriter if first frame
            if frame_idx == 0:
                combined_width = width * 2
                combined_height = height
                out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (combined_width, combined_height))
       
            if frame_idx % 15 == 0 or not table_set:
                table_results = table_model(frame)[0]
                if table_results.masks:
                    mask = table_results.masks[0].data[0].cpu().numpy()
                    mask_resized = cv2.resize(mask, (width, height))
                    #========EXPANSION=============
                    # Binarize the mask
                    mask_binary = (mask_resized > 0.5).astype(np.uint8)

                    # --- ADD DILATION HERE (5% expansion) ---
                    # Calculate kernel size as 5% of the larger mask dimension
                    kernel_size = int(0.05 * max(width, height))
                    kernel_size = max(3, kernel_size | 1)  # Ensure kernel size is odd and >= 3

                    # Create dilation kernel (elliptical is more natural for blobs)
                    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

                    # Dilate the binary mask
                    mask_dilated = cv2.dilate(mask_binary, kernel, iterations=1)
                    #========EXPANSION=============

                    contours, _ = cv2.findContours((mask_dilated * 255).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    if contours:
                        contour = max(contours, key=cv2.contourArea)
                        epsilon = 0.05 * cv2.arcLength(contour, True)
                        approx = cv2.approxPolyDP(contour, epsilon, True)
                        
                        src_pts = order_points_stable([pt[0] for pt in approx])
                        dst_pts = np.array([
                        [0, 0],         # top-left
                        [400, 0],       # top-right
                        [400, 800],     # bottom-right
                        [0, 800]        # bottom-left
                        ], dtype=np.float32)

                        homography, _ = cv2.findHomography(src_pts, dst_pts)
                        table_set = True

            # ========== 1. Detect TABLE once ==========
            # Assume models accept NumPy arrays now
            table_results = table_model(frame)[0]
            if not table_results.masks:
                frame_idx += 1
                continue

            mask = table_results.masks[0].data[0].cpu().numpy()
            mask_resized = cv2.resize(mask, (width, height))

            #========EXPANSION=============
            # Binarize the mask
            mask_binary = (mask_resized > 0.5).astype(np.uint8)

            # --- ADD DILATION HERE (5% expansion) ---
            # Calculate kernel size as 5% of the larger mask dimension
            kernel_size = int(0.05 * max(width, height))
            kernel_size = max(3, kernel_size | 1)  # Ensure kernel size is odd and >= 3

            # Create dilation kernel (elliptical is more natural for blobs)
            kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))

            # Dilate the binary mask
            mask_dilated = cv2.dilate(mask_binary, kernel, iterations=1)
            #========EXPANSION=============

            contours, _ = cv2.findContours((mask_dilated * 255).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            
            contour = max(contours, key=cv2.contourArea)
            epsilon = 0.05 * cv2.arcLength(contour, True)
            approx = cv2.approxPolyDP(contour, epsilon, True)

            src_pts = order_points_stable([pt[0] for pt in approx])
            dst_pts = np.array([
                [0, 0],         # top-left
                [400, 0],       # top-right
                [400, 800],     # bottom-right
                [0, 800]        # bottom-left
                ], dtype=np.float32)
            homography, _ = cv2.findHomography(src_pts, dst_pts)

            if homography is None:
                print("Failed to compute homography matrix.")
                return

            table_set = True
            print("✅ Table detected and homography set.")

            # ========== 2. Detect BALLS ==========
            ball_results = ball_model(frame)[0]
            mapped_positions, ball_labels = [], []

            for box in ball_results.boxes:
                x_c = box.xywh[0][0].item()
                y_c = box.xywh[0][1].item()
                x_int = int(np.clip(x_c, 0, width - 1))
                y_int = int(np.clip(y_c, 0, height - 1))

                if mask_dilated[y_int, x_int] < 0.5:
                    continue

                pt = np.array([[[x_c, y_c]]], dtype=np.float32)
                dst = cv2.perspectiveTransform(pt, homography)[0][0]

                if 0 <= dst[0] <= dst_width and 0 <= dst[1] <= dst_height:
                    mapped_positions.append(dst)
                    ball_labels.append(int(box.cls[0].item()))
                # else:
                #     print(f"⚠️ Mapped out-of-bound: ({dst[0]:.1f}, {dst[1]:.1f})")

            # ========== 3. Draw 2D Top-Down View ==========
            table_view = np.zeros((int(dst_height), int(dst_width), 3), dtype=np.uint8)
            table_view[:] = (26, 99, 15) # dark green

            for (x, y), label in zip(mapped_positions, ball_labels):
                cv2.circle(table_view, (int(x), int(y)), 8, (255, 255, 255), -1)
                cv2.putText(table_view, ball_label_to_name[label], (int(x) - 10, int(y) - 12),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1)

            table_view_resized = cv2.resize(table_view, (frame.shape[1], frame.shape[0]))
            combined = np.hstack((table_view_resized, frame.copy()))

            # ========== 4. Combine Views with Titles ==========
            cv2.putText(combined, "2D Table View", (50, 40),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)
            cv2.putText(combined, "Original Video", (width + 50, 40),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2)

            out.write(combined)
            frame_idx += 1
            print(f"{frame_idx}/{frames_to_process} : {(frame_idx/frames_to_process) *100}%")

    cap.release()
    out.release()
    print(f"✅ Output video saved to: {output_path}")

# %%
detect_table_and_map_balls_from_video("video_input/vid1.mp4")
# Out:
# 0: 640x384 (no detections), 148.6ms
# Speed: 3.1ms preprocess, 148.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 143.4ms
# Speed: 2.0ms preprocess, 143.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 140.3ms
# Speed: 2.0ms preprocess, 140.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 163.4ms
# Speed: 4.3ms preprocess, 163.4ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 1 8_ball, 4 stripes, 7 solids, 99.3ms
# Speed: 2.0ms preprocess, 99.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# 2/253 : 0.7905138339920948%
#
# 0: 640x384 2 table_play_areas, 133.7ms
# Speed: 2.1ms preprocess, 133.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 2 stripes, 8 solids, 123.1ms
# Speed: 2.3ms preprocess, 123.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 3/253 : 1.185770750988142%
#
# 0: 640x384 1 table_play_area, 133.6ms
# Speed: 2.1ms preprocess, 133.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 5 8_balls, 3 stripes, 7 solids, 118.7ms
# Speed: 2.1ms preprocess, 118.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 4/253 : 1.5810276679841897%
#
# 0: 640x384 1 table_play_area, 130.6ms
# Speed: 2.1ms preprocess, 130.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 4 stripes, 8 solids, 105.1ms
# Speed: 2.9ms preprocess, 105.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 5/253 : 1.9762845849802373%
#
# 0: 640x384 1 table_play_area, 134.9ms
# Speed: 2.0ms preprocess, 134.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 3 8_balls, 6 stripes, 8 solids, 100.6ms
# Speed: 1.8ms preprocess, 100.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 6/253 : 2.371541501976284%
#
# 0: 640x384 1 table_play_area, 181.5ms
# Speed: 2.1ms preprocess, 181.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 6 8_balls, 2 stripes, 9 solids, 112.6ms
# Speed: 2.2ms preprocess, 112.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 7/253 : 2.766798418972332%
#
# 0: 640x384 1 table_play_area, 135.4ms
# Speed: 2.1ms preprocess, 135.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 5 stripes, 6 solids, 109.5ms
# Speed: 2.2ms preprocess, 109.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 8/253 : 3.1620553359683794%
#
# 0: 640x384 1 table_play_area, 135.7ms
# Speed: 2.7ms preprocess, 135.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 6 stripes, 6 solids, 111.9ms
# Speed: 1.9ms preprocess, 111.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 9/253 : 3.557312252964427%
#
# 0: 640x384 1 table_play_area, 137.8ms
# Speed: 2.0ms preprocess, 137.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 7 solids, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 10/253 : 3.9525691699604746%
#
# 0: 640x384 1 table_play_area, 135.1ms
# Speed: 2.1ms preprocess, 135.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 3 stripes, 8 solids, 112.3ms
# Speed: 2.4ms preprocess, 112.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 11/253 : 4.3478260869565215%
#
# 0: 640x384 1 table_play_area, 130.7ms
# Speed: 2.1ms preprocess, 130.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 4 stripes, 6 solids, 124.1ms
# Speed: 2.2ms preprocess, 124.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 12/253 : 4.743083003952568%
#
# 0: 640x384 1 table_play_area, 133.7ms
# Speed: 2.2ms preprocess, 133.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 2 stripes, 6 solids, 119.9ms
# Speed: 2.5ms preprocess, 119.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 13/253 : 5.138339920948617%
#
# 0: 640x384 1 table_play_area, 138.1ms
# Speed: 3.1ms preprocess, 138.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 3 stripes, 8 solids, 102.6ms
# Speed: 1.9ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 14/253 : 5.533596837944664%
#
# 0: 640x384 1 table_play_area, 134.5ms
# Speed: 2.1ms preprocess, 134.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 1 stripe, 7 solids, 103.8ms
# Speed: 1.9ms preprocess, 103.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 15/253 : 5.928853754940711%
#
# 0: 640x384 1 table_play_area, 132.1ms
# Speed: 2.0ms preprocess, 132.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 131.3ms
# Speed: 2.1ms preprocess, 131.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 3 stripes, 10 solids, 100.7ms
# Speed: 1.9ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 16/253 : 6.324110671936759%
#
# 0: 640x384 1 table_play_area, 129.8ms
# Speed: 2.1ms preprocess, 129.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 2 stripes, 7 solids, 123.9ms
# Speed: 2.5ms preprocess, 123.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 17/253 : 6.719367588932807%
#
# 0: 640x384 1 table_play_area, 131.0ms
# Speed: 2.0ms preprocess, 131.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 1 stripe, 7 solids, 149.9ms
# Speed: 2.1ms preprocess, 149.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 18/253 : 7.114624505928854%
#
# 0: 640x384 1 table_play_area, 134.3ms
# Speed: 2.5ms preprocess, 134.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 7 solids, 115.5ms
# Speed: 2.3ms preprocess, 115.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 19/253 : 7.5098814229249005%
#
# 0: 640x384 1 table_play_area, 124.2ms
# Speed: 2.1ms preprocess, 124.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 7 solids, 117.4ms
# Speed: 3.2ms preprocess, 117.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 20/253 : 7.905138339920949%
#
# 0: 640x384 1 table_play_area, 134.6ms
# Speed: 2.3ms preprocess, 134.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 1 stripe, 9 solids, 120.9ms
# Speed: 2.3ms preprocess, 120.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 21/253 : 8.300395256916996%
#
# 0: 640x384 1 table_play_area, 134.8ms
# Speed: 2.1ms preprocess, 134.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 5 stripes, 9 solids, 119.3ms
# Speed: 3.2ms preprocess, 119.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 22/253 : 8.695652173913043%
#
# 0: 640x384 1 table_play_area, 131.5ms
# Speed: 2.1ms preprocess, 131.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 6 solids, 116.2ms
# Speed: 2.2ms preprocess, 116.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 23/253 : 9.090909090909092%
#
# 0: 640x384 1 table_play_area, 132.6ms
# Speed: 2.1ms preprocess, 132.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 4 stripes, 7 solids, 147.2ms
# Speed: 2.7ms preprocess, 147.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 24/253 : 9.486166007905137%
#
# 0: 640x384 1 table_play_area, 156.9ms
# Speed: 2.5ms preprocess, 156.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 4 stripes, 9 solids, 131.7ms
# Speed: 2.1ms preprocess, 131.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 25/253 : 9.881422924901186%
#
# 0: 640x384 1 table_play_area, 131.1ms
# Speed: 2.1ms preprocess, 131.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 3 stripes, 8 solids, 256.4ms
# Speed: 2.6ms preprocess, 256.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 26/253 : 10.276679841897234%
#
# 0: 640x384 1 table_play_area, 176.2ms
# Speed: 106.5ms preprocess, 176.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 9 solids, 130.1ms
# Speed: 2.2ms preprocess, 130.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 27/253 : 10.67193675889328%
#
# 0: 640x384 1 table_play_area, 132.6ms
# Speed: 2.4ms preprocess, 132.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 3 stripes, 8 solids, 108.3ms
# Speed: 2.0ms preprocess, 108.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 28/253 : 11.067193675889328%
#
# 0: 640x384 1 table_play_area, 130.4ms
# Speed: 2.5ms preprocess, 130.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 3 stripes, 6 solids, 122.1ms
# Speed: 2.5ms preprocess, 122.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# 29/253 : 11.462450592885375%
#
# 0: 640x384 1 table_play_area, 131.1ms
# Speed: 2.1ms preprocess, 131.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 1 stripe, 8 solids, 129.7ms
# Speed: 2.3ms preprocess, 129.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 30/253 : 11.857707509881422%
#
# 0: 640x384 1 table_play_area, 133.4ms
# Speed: 2.1ms preprocess, 133.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 147.0ms
# Speed: 2.3ms preprocess, 147.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 7 solids, 117.8ms
# Speed: 2.1ms preprocess, 117.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 31/253 : 12.25296442687747%
#
# 0: 640x384 2 table_play_areas, 132.7ms
# Speed: 2.0ms preprocess, 132.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 4 stripes, 10 solids, 115.2ms
# Speed: 2.3ms preprocess, 115.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 32/253 : 12.648221343873518%
#
# 0: 640x384 1 table_play_area, 130.1ms
# Speed: 2.2ms preprocess, 130.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 3 stripes, 7 solids, 130.9ms
# Speed: 4.4ms preprocess, 130.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 33/253 : 13.043478260869565%
#
# 0: 640x384 1 table_play_area, 129.4ms
# Speed: 2.6ms preprocess, 129.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 4 stripes, 7 solids, 137.6ms
# Speed: 1.9ms preprocess, 137.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 34/253 : 13.438735177865613%
#
# 0: 640x384 1 table_play_area, 136.0ms
# Speed: 2.1ms preprocess, 136.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 3 stripes, 9 solids, 157.9ms
# Speed: 4.0ms preprocess, 157.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# 35/253 : 13.83399209486166%
#
# 0: 640x384 1 table_play_area, 165.7ms
# Speed: 2.1ms preprocess, 165.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 3 stripes, 8 solids, 123.5ms
# Speed: 2.4ms preprocess, 123.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 36/253 : 14.229249011857709%
#
# 0: 640x384 1 table_play_area, 136.6ms
# Speed: 2.1ms preprocess, 136.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 7 solids, 115.4ms
# Speed: 2.2ms preprocess, 115.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 37/253 : 14.624505928853754%
#
# 0: 640x384 1 table_play_area, 138.3ms
# Speed: 2.0ms preprocess, 138.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 1 stripe, 10 solids, 112.2ms
# Speed: 2.4ms preprocess, 112.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 38/253 : 15.019762845849801%
#
# 0: 640x384 1 table_play_area, 138.1ms
# Speed: 2.1ms preprocess, 138.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 2 stripes, 7 solids, 113.1ms
# Speed: 1.9ms preprocess, 113.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 39/253 : 15.41501976284585%
#
# 0: 640x384 1 table_play_area, 138.6ms
# Speed: 2.7ms preprocess, 138.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 1 stripe, 9 solids, 122.8ms
# Speed: 2.2ms preprocess, 122.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 40/253 : 15.810276679841898%
#
# 0: 640x384 1 table_play_area, 133.8ms
# Speed: 2.1ms preprocess, 133.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 1 stripe, 8 solids, 126.6ms
# Speed: 2.1ms preprocess, 126.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 41/253 : 16.205533596837945%
#
# 0: 640x384 1 table_play_area, 135.5ms
# Speed: 2.8ms preprocess, 135.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 9 solids, 118.8ms
# Speed: 2.5ms preprocess, 118.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 42/253 : 16.600790513833992%
#
# 0: 640x384 1 table_play_area, 137.6ms
# Speed: 2.1ms preprocess, 137.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 1 stripe, 7 solids, 123.5ms
# Speed: 2.1ms preprocess, 123.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 43/253 : 16.99604743083004%
#
# 0: 640x384 1 table_play_area, 135.7ms
# Speed: 2.1ms preprocess, 135.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 7 solids, 122.5ms
# Speed: 2.3ms preprocess, 122.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 44/253 : 17.391304347826086%
#
# 0: 640x384 1 table_play_area, 135.5ms
# Speed: 2.1ms preprocess, 135.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 3 stripes, 7 solids, 121.4ms
# Speed: 2.2ms preprocess, 121.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 45/253 : 17.786561264822133%
#
# 0: 640x384 1 table_play_area, 133.0ms
# Speed: 2.6ms preprocess, 133.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 152.8ms
# Speed: 2.2ms preprocess, 152.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 8 solids, 122.6ms
# Speed: 2.1ms preprocess, 122.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 46/253 : 18.181818181818183%
#
# 0: 640x384 1 table_play_area, 137.9ms
# Speed: 2.1ms preprocess, 137.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 8 solids, 125.5ms
# Speed: 3.3ms preprocess, 125.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 47/253 : 18.57707509881423%
#
# 0: 640x384 1 table_play_area, 142.0ms
# Speed: 3.3ms preprocess, 142.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 3 stripes, 8 solids, 123.9ms
# Speed: 2.2ms preprocess, 123.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 48/253 : 18.972332015810274%
#
# 0: 640x384 1 table_play_area, 137.1ms
# Speed: 2.7ms preprocess, 137.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 3 stripes, 7 solids, 101.7ms
# Speed: 1.8ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 49/253 : 19.367588932806324%
#
# 0: 640x384 1 table_play_area, 124.9ms
# Speed: 2.0ms preprocess, 124.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 9 solids, 115.4ms
# Speed: 2.2ms preprocess, 115.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 50/253 : 19.76284584980237%
#
# 0: 640x384 1 table_play_area, 132.2ms
# Speed: 2.1ms preprocess, 132.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 9 solids, 112.3ms
# Speed: 2.0ms preprocess, 112.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 51/253 : 20.158102766798418%
#
# 0: 640x384 1 table_play_area, 132.7ms
# Speed: 2.8ms preprocess, 132.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 1 stripe, 8 solids, 120.0ms
# Speed: 2.4ms preprocess, 120.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 52/253 : 20.55335968379447%
#
# 0: 640x384 1 table_play_area, 134.0ms
# Speed: 2.1ms preprocess, 134.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 9 solids, 121.9ms
# Speed: 3.1ms preprocess, 121.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 53/253 : 20.948616600790515%
#
# 0: 640x384 1 table_play_area, 136.9ms
# Speed: 2.1ms preprocess, 136.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 1 stripe, 9 solids, 123.4ms
# Speed: 1.9ms preprocess, 123.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 54/253 : 21.34387351778656%
#
# 0: 640x384 1 table_play_area, 134.1ms
# Speed: 2.2ms preprocess, 134.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 9 solids, 108.6ms
# Speed: 2.4ms preprocess, 108.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 55/253 : 21.73913043478261%
#
# 0: 640x384 1 table_play_area, 140.0ms
# Speed: 2.6ms preprocess, 140.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 1 stripe, 10 solids, 110.0ms
# Speed: 2.3ms preprocess, 110.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 56/253 : 22.134387351778656%
#
# 0: 640x384 1 table_play_area, 132.8ms
# Speed: 2.1ms preprocess, 132.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 2 stripes, 8 solids, 119.3ms
# Speed: 2.5ms preprocess, 119.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 57/253 : 22.529644268774703%
#
# 0: 640x384 1 table_play_area, 131.3ms
# Speed: 2.0ms preprocess, 131.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 8 solids, 118.8ms
# Speed: 2.2ms preprocess, 118.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 58/253 : 22.92490118577075%
#
# 0: 640x384 1 table_play_area, 135.3ms
# Speed: 2.2ms preprocess, 135.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 3 stripes, 10 solids, 111.3ms
# Speed: 2.0ms preprocess, 111.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 59/253 : 23.3201581027668%
#
# 0: 640x384 1 table_play_area, 134.7ms
# Speed: 2.0ms preprocess, 134.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 4 stripes, 10 solids, 104.5ms
# Speed: 2.0ms preprocess, 104.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 60/253 : 23.715415019762844%
#
# 0: 640x384 1 table_play_area, 134.4ms
# Speed: 2.1ms preprocess, 134.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 174.7ms
# Speed: 2.4ms preprocess, 174.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 1 stripe, 10 solids, 132.4ms
# Speed: 2.3ms preprocess, 132.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 61/253 : 24.110671936758894%
#
# 0: 640x384 1 table_play_area, 133.2ms
# Speed: 2.7ms preprocess, 133.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 2 stripes, 10 solids, 124.2ms
# Speed: 2.1ms preprocess, 124.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 62/253 : 24.50592885375494%
#
# 0: 640x384 1 table_play_area, 134.1ms
# Speed: 2.4ms preprocess, 134.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 2 8_balls, 8 solids, 122.0ms
# Speed: 2.3ms preprocess, 122.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 63/253 : 24.90118577075099%
#
# 0: 640x384 1 table_play_area, 133.1ms
# Speed: 2.2ms preprocess, 133.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 3 8_balls, 8 stripes, 13 solids, 113.5ms
# Speed: 2.2ms preprocess, 113.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 64/253 : 25.296442687747035%
#
# 0: 640x384 1 table_play_area, 131.0ms
# Speed: 2.1ms preprocess, 131.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 3 8_balls, 3 stripes, 14 solids, 124.6ms
# Speed: 2.2ms preprocess, 124.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 65/253 : 25.691699604743086%
#
# 0: 640x384 1 table_play_area, 134.9ms
# Speed: 2.2ms preprocess, 134.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 5 8_balls, 4 stripes, 13 solids, 124.2ms
# Speed: 2.6ms preprocess, 124.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 66/253 : 26.08695652173913%
#
# 0: 640x384 1 table_play_area, 131.1ms
# Speed: 2.2ms preprocess, 131.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 6 stripes, 12 solids, 134.9ms
# Speed: 2.7ms preprocess, 134.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 67/253 : 26.48221343873518%
#
# 0: 640x384 1 table_play_area, 138.1ms
# Speed: 2.2ms preprocess, 138.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 5 stripes, 10 solids, 121.5ms
# Speed: 2.2ms preprocess, 121.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 68/253 : 26.877470355731226%
#
# 0: 640x384 1 table_play_area, 132.0ms
# Speed: 2.1ms preprocess, 132.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 7 8_balls, 3 stripes, 13 solids, 119.7ms
# Speed: 3.0ms preprocess, 119.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 69/253 : 27.27272727272727%
#
# 0: 640x384 1 table_play_area, 188.9ms
# Speed: 2.1ms preprocess, 188.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 3 stripes, 13 solids, 130.0ms
# Speed: 2.4ms preprocess, 130.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 70/253 : 27.66798418972332%
#
# 0: 640x384 1 table_play_area, 133.9ms
# Speed: 2.1ms preprocess, 133.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 6 stripes, 13 solids, 126.0ms
# Speed: 3.7ms preprocess, 126.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 71/253 : 28.063241106719367%
#
# 0: 640x384 (no detections), 134.0ms
# Speed: 2.1ms preprocess, 134.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 128.4ms
# Speed: 2.2ms preprocess, 128.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 128.9ms
# Speed: 2.2ms preprocess, 128.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 124.3ms
# Speed: 2.2ms preprocess, 124.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 136.9ms
# Speed: 2.1ms preprocess, 136.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 126.3ms
# Speed: 2.4ms preprocess, 126.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.1ms
# Speed: 2.2ms preprocess, 131.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 130.9ms
# Speed: 2.7ms preprocess, 130.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 4 stripes, 11 solids, 111.8ms
# Speed: 2.6ms preprocess, 111.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 78/253 : 30.8300395256917%
#
# 0: 640x384 1 table_play_area, 134.7ms
# Speed: 2.0ms preprocess, 134.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 4 stripes, 12 solids, 122.4ms
# Speed: 2.4ms preprocess, 122.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 79/253 : 31.225296442687743%
#
# 0: 640x384 1 table_play_area, 136.5ms
# Speed: 2.1ms preprocess, 136.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 3 stripes, 10 solids, 117.0ms
# Speed: 2.7ms preprocess, 117.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 80/253 : 31.620553359683797%
#
# 0: 640x384 (no detections), 134.2ms
# Speed: 2.1ms preprocess, 134.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.6ms
# Speed: 2.1ms preprocess, 131.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.4ms
# Speed: 2.1ms preprocess, 131.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 129.2ms
# Speed: 2.2ms preprocess, 129.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 135.3ms
# Speed: 2.2ms preprocess, 135.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 126.9ms
# Speed: 2.1ms preprocess, 126.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 183.8ms
# Speed: 2.1ms preprocess, 183.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 130.3ms
# Speed: 2.1ms preprocess, 130.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 131.1ms
# Speed: 2.6ms preprocess, 131.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 134.4ms
# Speed: 2.2ms preprocess, 134.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 132.1ms
# Speed: 2.2ms preprocess, 132.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 154.5ms
# Speed: 2.4ms preprocess, 154.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 3 stripes, 10 solids, 126.3ms
# Speed: 2.6ms preprocess, 126.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 91/253 : 35.96837944664031%
#
# 0: 640x384 1 table_play_area, 132.4ms
# Speed: 2.2ms preprocess, 132.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 3 stripes, 12 solids, 121.9ms
# Speed: 2.5ms preprocess, 121.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 92/253 : 36.36363636363637%
#
# 0: 640x384 1 table_play_area, 137.4ms
# Speed: 2.2ms preprocess, 137.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 6 stripes, 8 solids, 110.6ms
# Speed: 2.0ms preprocess, 110.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 93/253 : 36.75889328063241%
#
# 0: 640x384 1 table_play_area, 136.6ms
# Speed: 2.3ms preprocess, 136.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 3 stripes, 9 solids, 122.0ms
# Speed: 2.4ms preprocess, 122.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 94/253 : 37.15415019762846%
#
# 0: 640x384 1 table_play_area, 129.5ms
# Speed: 2.4ms preprocess, 129.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 9 solids, 117.6ms
# Speed: 2.4ms preprocess, 117.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 95/253 : 37.54940711462451%
#
# 0: 640x384 1 table_play_area, 133.4ms
# Speed: 2.1ms preprocess, 133.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 1 stripe, 9 solids, 117.2ms
# Speed: 2.1ms preprocess, 117.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 96/253 : 37.94466403162055%
#
# 0: 640x384 1 table_play_area, 129.9ms
# Speed: 2.1ms preprocess, 129.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 11 solids, 123.2ms
# Speed: 2.1ms preprocess, 123.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 97/253 : 38.3399209486166%
#
# 0: 640x384 1 table_play_area, 131.7ms
# Speed: 2.8ms preprocess, 131.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 1 stripe, 11 solids, 125.0ms
# Speed: 2.4ms preprocess, 125.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 98/253 : 38.73517786561265%
#
# 0: 640x384 1 table_play_area, 191.7ms
# Speed: 2.1ms preprocess, 191.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 1 stripe, 8 solids, 126.6ms
# Speed: 2.4ms preprocess, 126.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 99/253 : 39.130434782608695%
#
# 0: 640x384 1 table_play_area, 132.8ms
# Speed: 2.2ms preprocess, 132.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 1 stripe, 11 solids, 124.3ms
# Speed: 2.7ms preprocess, 124.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 100/253 : 39.52569169960474%
#
# 0: 640x384 1 table_play_area, 131.1ms
# Speed: 2.8ms preprocess, 131.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 11 solids, 116.8ms
# Speed: 2.0ms preprocess, 116.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 101/253 : 39.920948616600796%
#
# 0: 640x384 1 table_play_area, 131.9ms
# Speed: 2.2ms preprocess, 131.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 12 solids, 101.5ms
# Speed: 1.9ms preprocess, 101.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 102/253 : 40.316205533596836%
#
# 0: 640x384 1 table_play_area, 134.3ms
# Speed: 2.0ms preprocess, 134.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 2 stripes, 11 solids, 118.3ms
# Speed: 2.2ms preprocess, 118.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 103/253 : 40.71146245059288%
#
# 0: 640x384 1 table_play_area, 135.5ms
# Speed: 2.7ms preprocess, 135.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 8 8_balls, 1 stripe, 10 solids, 118.4ms
# Speed: 2.3ms preprocess, 118.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 104/253 : 41.10671936758894%
#
# 0: 640x384 1 table_play_area, 133.1ms
# Speed: 2.1ms preprocess, 133.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 2 stripes, 10 solids, 129.5ms
# Speed: 2.1ms preprocess, 129.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 105/253 : 41.50197628458498%
#
# 0: 640x384 1 table_play_area, 139.1ms
# Speed: 2.1ms preprocess, 139.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 163.2ms
# Speed: 3.6ms preprocess, 163.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 4 stripes, 9 solids, 121.0ms
# Speed: 2.1ms preprocess, 121.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 106/253 : 41.89723320158103%
#
# 0: 640x384 1 table_play_area, 131.0ms
# Speed: 2.6ms preprocess, 131.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 3 stripes, 10 solids, 137.8ms
# Speed: 2.6ms preprocess, 137.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 107/253 : 42.29249011857708%
#
# 0: 640x384 1 table_play_area, 136.8ms
# Speed: 2.2ms preprocess, 136.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 12 solids, 119.3ms
# Speed: 2.4ms preprocess, 119.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 108/253 : 42.68774703557312%
#
# 0: 640x384 1 table_play_area, 132.5ms
# Speed: 2.2ms preprocess, 132.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 3 stripes, 14 solids, 129.4ms
# Speed: 2.6ms preprocess, 129.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 109/253 : 43.08300395256917%
#
# 0: 640x384 1 table_play_area, 136.2ms
# Speed: 2.1ms preprocess, 136.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 2 stripes, 11 solids, 121.1ms
# Speed: 2.0ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 110/253 : 43.47826086956522%
#
# 0: 640x384 1 table_play_area, 135.0ms
# Speed: 2.1ms preprocess, 135.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 3 stripes, 12 solids, 127.3ms
# Speed: 2.7ms preprocess, 127.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 111/253 : 43.873517786561266%
#
# 0: 640x384 1 table_play_area, 133.1ms
# Speed: 2.1ms preprocess, 133.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 1 stripe, 13 solids, 102.3ms
# Speed: 1.8ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 112/253 : 44.26877470355731%
#
# 0: 640x384 1 table_play_area, 134.4ms
# Speed: 2.4ms preprocess, 134.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 3 stripes, 11 solids, 121.0ms
# Speed: 2.3ms preprocess, 121.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 113/253 : 44.66403162055336%
#
# 0: 640x384 1 table_play_area, 134.6ms
# Speed: 2.1ms preprocess, 134.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 11 solids, 126.6ms
# Speed: 2.8ms preprocess, 126.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 114/253 : 45.059288537549406%
#
# 0: 640x384 1 table_play_area, 143.4ms
# Speed: 2.1ms preprocess, 143.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 9 solids, 127.6ms
# Speed: 2.4ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 115/253 : 45.45454545454545%
#
# 0: 640x384 (no detections), 132.8ms
# Speed: 2.2ms preprocess, 132.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 130.2ms
# Speed: 2.2ms preprocess, 130.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 2 stripes, 9 solids, 120.7ms
# Speed: 2.3ms preprocess, 120.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 117/253 : 46.24505928853755%
#
# 0: 640x384 1 table_play_area, 130.9ms
# Speed: 2.1ms preprocess, 130.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 16 8_balls, 2 stripes, 12 solids, 119.2ms
# Speed: 2.4ms preprocess, 119.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 118/253 : 46.6403162055336%
#
# 0: 640x384 1 table_play_area, 131.1ms
# Speed: 2.0ms preprocess, 131.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 1 stripe, 11 solids, 119.9ms
# Speed: 2.2ms preprocess, 119.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 119/253 : 47.03557312252965%
#
# 0: 640x384 1 table_play_area, 130.6ms
# Speed: 2.2ms preprocess, 130.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 10 solids, 127.6ms
# Speed: 2.5ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 120/253 : 47.43083003952569%
#
# 0: 640x384 1 table_play_area, 133.3ms
# Speed: 2.1ms preprocess, 133.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 165.2ms
# Speed: 2.4ms preprocess, 165.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 2 stripes, 11 solids, 126.3ms
# Speed: 2.5ms preprocess, 126.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 121/253 : 47.82608695652174%
#
# 0: 640x384 1 table_play_area, 133.9ms
# Speed: 2.1ms preprocess, 133.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 11 solids, 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 122/253 : 48.22134387351779%
#
# 0: 640x384 1 table_play_area, 136.1ms
# Speed: 2.3ms preprocess, 136.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 1 stripe, 9 solids, 111.7ms
# Speed: 2.4ms preprocess, 111.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 123/253 : 48.616600790513836%
#
# 0: 640x384 1 table_play_area, 140.4ms
# Speed: 2.4ms preprocess, 140.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 1 stripe, 9 solids, 106.4ms
# Speed: 1.9ms preprocess, 106.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 124/253 : 49.01185770750988%
#
# 0: 640x384 1 table_play_area, 143.0ms
# Speed: 2.2ms preprocess, 143.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 9 solids, 124.3ms
# Speed: 2.3ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 125/253 : 49.40711462450593%
#
# 0: 640x384 1 table_play_area, 135.5ms
# Speed: 2.1ms preprocess, 135.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 1 stripe, 11 solids, 122.9ms
# Speed: 2.2ms preprocess, 122.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 126/253 : 49.80237154150198%
#
# 0: 640x384 1 table_play_area, 131.5ms
# Speed: 2.6ms preprocess, 131.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 3 stripes, 10 solids, 119.6ms
# Speed: 2.1ms preprocess, 119.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 127/253 : 50.19762845849802%
#
# 0: 640x384 1 table_play_area, 134.4ms
# Speed: 2.0ms preprocess, 134.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 15 8_balls, 1 stripe, 10 solids, 124.1ms
# Speed: 2.7ms preprocess, 124.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 128/253 : 50.59288537549407%
#
# 0: 640x384 1 table_play_area, 188.0ms
# Speed: 2.8ms preprocess, 188.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 1 stripe, 9 solids, 100.5ms
# Speed: 1.9ms preprocess, 100.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 129/253 : 50.988142292490124%
#
# 0: 640x384 1 table_play_area, 134.4ms
# Speed: 2.4ms preprocess, 134.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 8 solids, 117.4ms
# Speed: 2.6ms preprocess, 117.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 130/253 : 51.38339920948617%
#
# 0: 640x384 1 table_play_area, 133.0ms
# Speed: 2.1ms preprocess, 133.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 9 solids, 123.3ms
# Speed: 3.5ms preprocess, 123.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 131/253 : 51.77865612648221%
#
# 0: 640x384 1 table_play_area, 141.7ms
# Speed: 2.2ms preprocess, 141.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 1 stripe, 11 solids, 117.2ms
# Speed: 2.4ms preprocess, 117.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 132/253 : 52.17391304347826%
#
# 0: 640x384 1 table_play_area, 131.4ms
# Speed: 2.7ms preprocess, 131.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 2 stripes, 9 solids, 118.8ms
# Speed: 2.1ms preprocess, 118.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 133/253 : 52.569169960474305%
#
# 0: 640x384 1 table_play_area, 133.9ms
# Speed: 2.1ms preprocess, 133.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 1 stripe, 10 solids, 114.0ms
# Speed: 2.8ms preprocess, 114.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 134/253 : 52.96442687747036%
#
# 0: 640x384 1 table_play_area, 132.6ms
# Speed: 2.1ms preprocess, 132.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 4 stripes, 9 solids, 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# 135/253 : 53.359683794466406%
#
# 0: 640x384 1 table_play_area, 128.1ms
# Speed: 2.7ms preprocess, 128.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 145.8ms
# Speed: 2.8ms preprocess, 145.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 9 solids, 105.6ms
# Speed: 2.7ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 136/253 : 53.75494071146245%
#
# 0: 640x384 1 table_play_area, 127.4ms
# Speed: 2.7ms preprocess, 127.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 8 solids, 95.1ms
# Speed: 2.3ms preprocess, 95.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 137/253 : 54.1501976284585%
#
# 0: 640x384 1 table_play_area, 135.8ms
# Speed: 2.0ms preprocess, 135.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 10 8_balls, 2 stripes, 9 solids, 153.2ms
# Speed: 2.5ms preprocess, 153.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 138/253 : 54.54545454545454%
#
# 0: 640x384 1 table_play_area, 145.4ms
# Speed: 2.0ms preprocess, 145.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 9 8_balls, 1 stripe, 10 solids, 122.8ms
# Speed: 2.0ms preprocess, 122.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 139/253 : 54.9407114624506%
#
# 0: 640x384 1 table_play_area, 135.9ms
# Speed: 2.2ms preprocess, 135.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 8 solids, 118.8ms
# Speed: 2.5ms preprocess, 118.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 140/253 : 55.33596837944664%
#
# 0: 640x384 1 table_play_area, 136.8ms
# Speed: 2.2ms preprocess, 136.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 2 stripes, 10 solids, 131.9ms
# Speed: 2.4ms preprocess, 131.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 141/253 : 55.73122529644269%
#
# 0: 640x384 1 table_play_area, 135.5ms
# Speed: 2.2ms preprocess, 135.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 1 stripe, 9 solids, 120.0ms
# Speed: 2.2ms preprocess, 120.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 142/253 : 56.126482213438734%
#
# 0: 640x384 1 table_play_area, 128.8ms
# Speed: 2.1ms preprocess, 128.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 1 stripe, 9 solids, 121.2ms
# ...
# Speed: 2.2ms preprocess, 133.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 3 stripes, 9 solids, 100.1ms
# Speed: 1.9ms preprocess, 100.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 210/253 : 83.00395256916995%
#
# 0: 640x384 1 table_play_area, 132.6ms
# Speed: 2.1ms preprocess, 132.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 153.4ms
# Speed: 2.1ms preprocess, 153.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 9 solids, 120.4ms
# Speed: 2.3ms preprocess, 120.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 211/253 : 83.399209486166%
#
# 0: 640x384 1 table_play_area, 131.0ms
# Speed: 2.3ms preprocess, 131.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 10 solids, 110.2ms
# Speed: 2.1ms preprocess, 110.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 212/253 : 83.79446640316206%
#
# 0: 640x384 1 table_play_area, 138.5ms
# Speed: 2.2ms preprocess, 138.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 7 solids, 110.8ms
# Speed: 2.2ms preprocess, 110.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 213/253 : 84.18972332015811%
#
# 0: 640x384 1 table_play_area, 132.2ms
# Speed: 2.1ms preprocess, 132.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 3 stripes, 8 solids, 100.0ms
# Speed: 2.3ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 214/253 : 84.58498023715416%
#
# 0: 640x384 1 table_play_area, 133.4ms
# Speed: 2.1ms preprocess, 133.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 5 stripes, 7 solids, 121.6ms
# Speed: 2.2ms preprocess, 121.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 215/253 : 84.98023715415019%
#
# 0: 640x384 1 table_play_area, 134.3ms
# Speed: 2.1ms preprocess, 134.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 5 stripes, 7 solids, 116.0ms
# Speed: 2.2ms preprocess, 116.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 216/253 : 85.37549407114624%
#
# 0: 640x384 1 table_play_area, 126.0ms
# Speed: 2.5ms preprocess, 126.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 6 solids, 108.4ms
# Speed: 2.1ms preprocess, 108.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 217/253 : 85.7707509881423%
#
# 0: 640x384 1 table_play_area, 133.8ms
# Speed: 2.2ms preprocess, 133.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 9 solids, 123.2ms
# Speed: 3.0ms preprocess, 123.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 218/253 : 86.16600790513834%
#
# 0: 640x384 1 table_play_area, 133.7ms
# Speed: 2.1ms preprocess, 133.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 9 solids, 123.1ms
# Speed: 2.0ms preprocess, 123.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 219/253 : 86.56126482213439%
#
# 0: 640x384 1 table_play_area, 133.2ms
# Speed: 2.0ms preprocess, 133.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 4 stripes, 10 solids, 122.5ms
# Speed: 2.3ms preprocess, 122.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 220/253 : 86.95652173913044%
#
# 0: 640x384 1 table_play_area, 134.3ms
# Speed: 2.1ms preprocess, 134.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 4 stripes, 9 solids, 117.9ms
# Speed: 2.3ms preprocess, 117.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 221/253 : 87.35177865612648%
#
# 0: 640x384 1 table_play_area, 131.8ms
# Speed: 2.1ms preprocess, 131.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 16 8_balls, 4 stripes, 9 solids, 118.5ms
# Speed: 2.2ms preprocess, 118.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 222/253 : 87.74703557312253%
#
# 0: 640x384 1 table_play_area, 136.5ms
# Speed: 2.2ms preprocess, 136.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 9 solids, 120.4ms
# Speed: 3.1ms preprocess, 120.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 223/253 : 88.14229249011858%
#
# 0: 640x384 1 table_play_area, 137.3ms
# Speed: 2.1ms preprocess, 137.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 4 stripes, 9 solids, 125.3ms
# Speed: 2.2ms preprocess, 125.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 224/253 : 88.53754940711462%
#
# 0: 640x384 1 table_play_area, 131.9ms
# Speed: 2.1ms preprocess, 131.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 8 solids, 126.8ms
# Speed: 2.2ms preprocess, 126.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 225/253 : 88.93280632411067%
#
# 0: 640x384 1 table_play_area, 136.1ms
# Speed: 2.1ms preprocess, 136.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 156.6ms
# Speed: 3.2ms preprocess, 156.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 6 stripes, 8 solids, 121.5ms
# Speed: 2.5ms preprocess, 121.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 226/253 : 89.32806324110672%
#
# 0: 640x384 1 table_play_area, 133.7ms
# Speed: 2.1ms preprocess, 133.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 4 stripes, 9 solids, 121.5ms
# Speed: 2.3ms preprocess, 121.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 227/253 : 89.72332015810277%
#
# 0: 640x384 1 table_play_area, 132.7ms
# Speed: 2.1ms preprocess, 132.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 2 stripes, 9 solids, 120.9ms
# Speed: 2.4ms preprocess, 120.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 228/253 : 90.11857707509881%
#
# 0: 640x384 1 table_play_area, 132.2ms
# Speed: 2.2ms preprocess, 132.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 7 solids, 122.6ms
# Speed: 2.2ms preprocess, 122.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 229/253 : 90.51383399209486%
#
# 0: 640x384 1 table_play_area, 131.6ms
# Speed: 2.1ms preprocess, 131.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 2 stripes, 7 solids, 120.4ms
# Speed: 2.2ms preprocess, 120.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 230/253 : 90.9090909090909%
#
# 0: 640x384 1 table_play_area, 131.0ms
# Speed: 2.3ms preprocess, 131.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 9 solids, 119.7ms
# Speed: 2.1ms preprocess, 119.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 231/253 : 91.30434782608695%
#
# 0: 640x384 1 table_play_area, 131.6ms
# Speed: 2.1ms preprocess, 131.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 4 stripes, 7 solids, 124.9ms
# Speed: 2.2ms preprocess, 124.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 232/253 : 91.699604743083%
#
# 0: 640x384 1 table_play_area, 143.9ms
# Speed: 2.2ms preprocess, 143.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 15 8_balls, 4 stripes, 7 solids, 120.6ms
# Speed: 2.4ms preprocess, 120.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 233/253 : 92.09486166007905%
#
# 0: 640x384 1 table_play_area, 134.0ms
# Speed: 2.0ms preprocess, 134.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 7 solids, 120.2ms
# Speed: 2.1ms preprocess, 120.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 234/253 : 92.4901185770751%
#
# 0: 640x384 1 table_play_area, 132.8ms
# Speed: 2.2ms preprocess, 132.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 15 8_balls, 2 stripes, 8 solids, 126.3ms
# Speed: 3.6ms preprocess, 126.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 235/253 : 92.88537549407114%
#
# 0: 640x384 1 table_play_area, 136.8ms
# Speed: 2.1ms preprocess, 136.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 2 stripes, 8 solids, 122.1ms
# Speed: 2.3ms preprocess, 122.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 236/253 : 93.2806324110672%
#
# 0: 640x384 1 table_play_area, 133.9ms
# Speed: 2.1ms preprocess, 133.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 4 stripes, 8 solids, 117.8ms
# Speed: 2.8ms preprocess, 117.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 237/253 : 93.67588932806325%
#
# 0: 640x384 1 table_play_area, 131.3ms
# Speed: 2.0ms preprocess, 131.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 2 stripes, 8 solids, 118.2ms
# Speed: 2.2ms preprocess, 118.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 238/253 : 94.0711462450593%
#
# 0: 640x384 1 table_play_area, 134.1ms
# Speed: 2.1ms preprocess, 134.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 3 stripes, 8 solids, 127.6ms
# Speed: 2.3ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 239/253 : 94.46640316205533%
#
# 0: 640x384 1 table_play_area, 134.0ms
# Speed: 2.1ms preprocess, 134.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 3 stripes, 8 solids, 103.5ms
# Speed: 2.3ms preprocess, 103.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# 240/253 : 94.86166007905138%
#
# 0: 640x384 1 table_play_area, 135.4ms
# Speed: 2.0ms preprocess, 135.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 table_play_area, 173.8ms
# Speed: 1.9ms preprocess, 173.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 3 stripes, 8 solids, 130.1ms
# Speed: 2.3ms preprocess, 130.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 241/253 : 95.25691699604744%
#
# 0: 640x384 1 table_play_area, 188.2ms
# Speed: 2.2ms preprocess, 188.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 15 8_balls, 3 stripes, 9 solids, 100.8ms
# Speed: 2.3ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 242/253 : 95.65217391304348%
#
# 0: 640x384 1 table_play_area, 140.0ms
# Speed: 2.1ms preprocess, 140.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 17 8_balls, 3 stripes, 9 solids, 120.4ms
# Speed: 2.5ms preprocess, 120.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 243/253 : 96.04743083003953%
#
# 0: 640x384 1 table_play_area, 137.6ms
# Speed: 2.1ms preprocess, 137.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 4 stripes, 9 solids, 124.1ms
# Speed: 2.2ms preprocess, 124.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 244/253 : 96.44268774703558%
#
# 0: 640x384 1 table_play_area, 133.2ms
# Speed: 2.2ms preprocess, 133.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 3 stripes, 8 solids, 126.6ms
# Speed: 2.4ms preprocess, 126.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 245/253 : 96.83794466403161%
#
# 0: 640x384 1 table_play_area, 134.8ms
# Speed: 2.1ms preprocess, 134.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 13 8_balls, 2 stripes, 8 solids, 122.7ms
# Speed: 2.3ms preprocess, 122.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 246/253 : 97.23320158102767%
#
# 0: 640x384 1 table_play_area, 130.6ms
# Speed: 2.3ms preprocess, 130.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 9 solids, 103.0ms
# Speed: 1.9ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 247/253 : 97.62845849802372%
#
# 0: 640x384 1 table_play_area, 144.6ms
# Speed: 2.0ms preprocess, 144.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 7 solids, 126.8ms
# Speed: 3.6ms preprocess, 126.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 248/253 : 98.02371541501977%
#
# 0: 640x384 1 table_play_area, 136.2ms
# Speed: 2.1ms preprocess, 136.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 3 stripes, 7 solids, 103.0ms
# Speed: 1.8ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 249/253 : 98.41897233201581%
#
# 0: 640x384 1 table_play_area, 135.2ms
# Speed: 1.9ms preprocess, 135.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 11 8_balls, 3 stripes, 7 solids, 120.5ms
# Speed: 2.2ms preprocess, 120.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 250/253 : 98.81422924901186%
#
# 0: 640x384 1 table_play_area, 131.4ms
# Speed: 2.3ms preprocess, 131.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 14 8_balls, 3 stripes, 7 solids, 118.7ms
# Speed: 2.6ms preprocess, 118.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 251/253 : 99.2094861660079%
#
# 0: 640x384 1 table_play_area, 147.6ms
# Speed: 2.2ms preprocess, 147.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 4 stripes, 8 solids, 118.5ms
# Speed: 2.5ms preprocess, 118.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 252/253 : 99.60474308300395%
#
# 0: 640x384 1 table_play_area, 133.8ms
# Speed: 2.0ms preprocess, 133.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# ✅ Table detected and homography set.
#
# 0: 640x384 12 8_balls, 2 stripes, 10 solids, 113.3ms
# Speed: 3.4ms preprocess, 113.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 253/253 : 100.0%
# ✅ Output video saved to: video_output/out_vid1.mp4

# %% [markdown]
# ### Show predictions on Video

# %%
def visualize_table_and_ball_predictions(video_path, output_path, max_frames=700):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"❌ Cannot open video: {video_path}")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_to_process = min(total_frames, max_frames)

    frame_idx = 0
    out = None  # Will be initialized after first frame

    while frame_idx < frames_to_process:
        ret, frame = cap.read()
        if not ret:
            break

        frame = correct_frame_orientation(frame)

        # Initialize VideoWriter AFTER getting true dimensions
        if out is None:
            height, width = frame.shape[:2]
            combined_width = width  # Only using single view here
            combined_height = height
            out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'),
                                  fps, (combined_width, combined_height))

        # 1. Predict table
        table_results = table_model(frame)[0]
        if table_results.masks:
            mask = table_results.masks[0].data[0].cpu().numpy()
            mask_resized = cv2.resize(mask, (width, height))
            contours, _ = cv2.findContours((mask_resized * 255).astype(np.uint8),
                                           cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if contours:
                cv2.drawContours(frame, contours, -1, (0, 255, 0), 2)

        # 2. Predict balls
        ball_results = ball_model(frame)[0]
        for box in ball_results.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cls_id = int(box.cls[0].item())
            conf = float(box.conf[0])
            label = ball_label_to_name.get(cls_id, f"Ball {cls_id}")
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
            cv2.putText(frame, f"{label} ({conf:.2f})", (x1, y1 - 8),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

        # 3. Frame index
        cv2.putText(frame, f"Frame: {frame_idx}", (10, frame.shape[0] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (200, 200, 200), 1)

        out.write(frame)
        frame_idx += 1
        print(f"{frame_idx}/{frames_to_process} : {(frame_idx / frames_to_process) * 100:.1f}%")

    cap.release()
    if out is not None:
        out.release()

    print(f"✅ Prediction video saved: {output_path}")

# %%
visualize_table_and_ball_predictions("video_input/tes.mp4", "video_output/tes_with_preds.mp4")
# Out:
# 0: 640x384 1 table_play_area, 187.8ms
# Speed: 5.0ms preprocess, 187.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 9 solids, 115.9ms
# Speed: 2.6ms preprocess, 115.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# 1/700 : 0.1%
#
# 0: 640x384 1 table_play_area, 192.8ms
# Speed: 2.7ms preprocess, 192.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 5 stripes, 8 solids, 102.0ms
# Speed: 2.6ms preprocess, 102.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 2/700 : 0.3%
#
# 0: 640x384 1 table_play_area, 140.6ms
# Speed: 2.4ms preprocess, 140.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 8_ball, 3 stripes, 10 solids, 105.3ms
# Speed: 2.2ms preprocess, 105.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 3/700 : 0.4%
#
# 0: 640x384 1 table_play_area, 188.2ms
# Speed: 2.6ms preprocess, 188.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 4 stripes, 9 solids, 107.4ms
# Speed: 3.4ms preprocess, 107.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 4/700 : 0.6%
#
# 0: 640x384 1 table_play_area, 133.9ms
# Speed: 2.7ms preprocess, 133.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 3 stripes, 10 solids, 103.8ms
# Speed: 2.6ms preprocess, 103.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 5/700 : 0.7%
#
# 0: 640x384 1 table_play_area, 143.6ms
# Speed: 2.4ms preprocess, 143.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 8 solids, 105.2ms
# Speed: 2.8ms preprocess, 105.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 6/700 : 0.9%
#
# 0: 640x384 1 table_play_area, 200.5ms
# Speed: 2.4ms preprocess, 200.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 2 stripes, 8 solids, 104.7ms
# Speed: 2.5ms preprocess, 104.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 7/700 : 1.0%
#
# 0: 640x384 1 table_play_area, 135.9ms
# Speed: 2.4ms preprocess, 135.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 2 stripes, 9 solids, 105.4ms
# Speed: 2.7ms preprocess, 105.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 8/700 : 1.1%
#
# 0: 640x384 1 table_play_area, 259.5ms
# Speed: 2.6ms preprocess, 259.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 8 solids, 105.5ms
# Speed: 2.8ms preprocess, 105.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 9/700 : 1.3%
#
# 0: 640x384 1 table_play_area, 138.9ms
# Speed: 2.2ms preprocess, 138.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 9 solids, 105.1ms
# Speed: 3.0ms preprocess, 105.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 10/700 : 1.4%
#
# 0: 640x384 1 table_play_area, 202.3ms
# Speed: 2.5ms preprocess, 202.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 3 stripes, 5 solids, 107.8ms
# Speed: 2.5ms preprocess, 107.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 11/700 : 1.6%
#
# 0: 640x384 1 table_play_area, 141.9ms
# Speed: 2.4ms preprocess, 141.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 8_ball, 5 stripes, 4 solids, 104.3ms
# Speed: 2.5ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 12/700 : 1.7%
#
# 0: 640x384 1 table_play_area, 137.7ms
# Speed: 2.5ms preprocess, 137.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 4 stripes, 7 solids, 103.9ms
# Speed: 2.8ms preprocess, 103.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 13/700 : 1.9%
#
# 0: 640x384 1 table_play_area, 138.9ms
# Speed: 2.9ms preprocess, 138.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 3 stripes, 6 solids, 105.4ms
# Speed: 2.1ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 14/700 : 2.0%
#
# 0: 640x384 1 table_play_area, 139.7ms
# Speed: 3.0ms preprocess, 139.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 2 stripes, 7 solids, 110.9ms
# Speed: 2.9ms preprocess, 110.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 15/700 : 2.1%
#
# 0: 640x384 1 table_play_area, 138.2ms
# Speed: 2.3ms preprocess, 138.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 4 stripes, 7 solids, 111.5ms
# Speed: 3.6ms preprocess, 111.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 16/700 : 2.3%
#
# 0: 640x384 1 table_play_area, 146.9ms
# Speed: 33.8ms preprocess, 146.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 4 stripes, 8 solids, 105.6ms
# Speed: 2.8ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 17/700 : 2.4%
#
# 0: 640x384 1 table_play_area, 136.4ms
# Speed: 2.3ms preprocess, 136.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 3 stripes, 6 solids, 107.6ms
# Speed: 2.4ms preprocess, 107.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 18/700 : 2.6%
#
# 0: 640x384 1 table_play_area, 137.2ms
# Speed: 2.7ms preprocess, 137.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 3 stripes, 7 solids, 104.2ms
# Speed: 2.7ms preprocess, 104.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 19/700 : 2.7%
#
# 0: 640x384 1 table_play_area, 169.4ms
# Speed: 2.5ms preprocess, 169.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 6 solids, 114.3ms
# Speed: 3.4ms preprocess, 114.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# 20/700 : 2.9%
#
# 0: 640x384 1 table_play_area, 136.9ms
# Speed: 3.2ms preprocess, 136.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 3 stripes, 8 solids, 104.3ms
# Speed: 2.1ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 21/700 : 3.0%
#
# 0: 640x384 1 table_play_area, 206.8ms
# Speed: 2.4ms preprocess, 206.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 1 stripe, 11 solids, 105.0ms
# Speed: 2.5ms preprocess, 105.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 22/700 : 3.1%
#
# 0: 640x384 1 table_play_area, 139.7ms
# Speed: 2.6ms preprocess, 139.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 8_ball, 2 stripes, 10 solids, 112.0ms
# Speed: 2.3ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 23/700 : 3.3%
#
# 0: 640x384 1 table_play_area, 158.5ms
# Speed: 3.2ms preprocess, 158.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 1 stripe, 10 solids, 112.7ms
# Speed: 2.9ms preprocess, 112.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 24/700 : 3.4%
#
# 0: 640x384 1 table_play_area, 139.0ms
# Speed: 2.2ms preprocess, 139.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 8 solids, 119.3ms
# Speed: 2.1ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 25/700 : 3.6%
#
# 0: 640x384 1 table_play_area, 140.0ms
# Speed: 2.1ms preprocess, 140.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 1 stripe, 7 solids, 102.0ms
# Speed: 2.5ms preprocess, 102.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 26/700 : 3.7%
#
# 0: 640x384 1 table_play_area, 262.8ms
# Speed: 2.3ms preprocess, 262.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 3 stripes, 10 solids, 121.8ms
# Speed: 3.0ms preprocess, 121.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 27/700 : 3.9%
#
# 0: 640x384 1 table_play_area, 133.5ms
# Speed: 2.3ms preprocess, 133.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 3 stripes, 9 solids, 103.4ms
# Speed: 2.5ms preprocess, 103.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 28/700 : 4.0%
#
# 0: 640x384 (no detections), 134.5ms
# Speed: 2.5ms preprocess, 134.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 2 stripes, 11 solids, 101.1ms
# Speed: 2.6ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 29/700 : 4.1%
#
# 0: 640x384 1 table_play_area, 134.0ms
# Speed: 2.4ms preprocess, 134.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 1 stripe, 10 solids, 100.3ms
# Speed: 3.1ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 30/700 : 4.3%
#
# 0: 640x384 1 table_play_area, 136.7ms
# Speed: 2.5ms preprocess, 136.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 solids, 101.1ms
# Speed: 2.5ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 31/700 : 4.4%
#
# 0: 640x384 1 table_play_area, 142.7ms
# Speed: 2.2ms preprocess, 142.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 stripes, 9 solids, 100.7ms
# Speed: 2.3ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 32/700 : 4.6%
#
# 0: 640x384 1 table_play_area, 133.6ms
# Speed: 2.3ms preprocess, 133.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 stripes, 9 solids, 102.5ms
# Speed: 2.5ms preprocess, 102.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# 33/700 : 4.7%
#
# 0: 640x384 1 table_play_area, 131.0ms
# Speed: 2.8ms preprocess, 131.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 4 stripes, 15 solids, 105.3ms
# Speed: 2.7ms preprocess, 105.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 34/700 : 4.9%
#
# 0: 640x384 1 table_play_area, 130.7ms
# Speed: 2.4ms preprocess, 130.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 6 stripes, 13 solids, 102.9ms
# Speed: 2.3ms preprocess, 102.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 35/700 : 5.0%
#
# 0: 640x384 1 table_play_area, 133.9ms
# Speed: 2.3ms preprocess, 133.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 7 stripes, 14 solids, 104.9ms
# Speed: 2.3ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 36/700 : 5.1%
#
# 0: 640x384 1 table_play_area, 134.7ms
# Speed: 2.4ms preprocess, 134.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 8_ball, 5 stripes, 15 solids, 101.1ms
# Speed: 2.3ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 37/700 : 5.3%
#
# 0: 640x384 1 table_play_area, 135.1ms
# Speed: 2.4ms preprocess, 135.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 1 stripe, 10 solids, 114.7ms
# Speed: 18.3ms preprocess, 114.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 38/700 : 5.4%
#
# 0: 640x384 1 table_play_area, 130.5ms
# Speed: 2.3ms preprocess, 130.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 7 stripes, 13 solids, 100.6ms
# Speed: 2.6ms preprocess, 100.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 39/700 : 5.6%
#
# 0: 640x384 1 table_play_area, 130.2ms
# Speed: 2.3ms preprocess, 130.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 4 stripes, 13 solids, 100.2ms
# Speed: 2.2ms preprocess, 100.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 40/700 : 5.7%
#
# 0: 640x384 1 table_play_area, 137.2ms
# Speed: 2.5ms preprocess, 137.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 8_balls, 4 stripes, 15 solids, 101.1ms
# Speed: 2.4ms preprocess, 101.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 41/700 : 5.9%
#
# 0: 640x384 1 table_play_area, 130.9ms
# Speed: 2.3ms preprocess, 130.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 5 stripes, 19 solids, 104.2ms
# Speed: 2.4ms preprocess, 104.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 42/700 : 6.0%
#
# 0: 640x384 1 table_play_area, 133.0ms
# Speed: 2.3ms preprocess, 133.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 3 stripes, 15 solids, 100.7ms
# Speed: 2.3ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 43/700 : 6.1%
#
# 0: 640x384 (no detections), 187.1ms
# Speed: 2.2ms preprocess, 187.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 2 stripes, 13 solids, 103.4ms
# Speed: 3.3ms preprocess, 103.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 44/700 : 6.3%
#
# 0: 640x384 (no detections), 131.7ms
# Speed: 2.2ms preprocess, 131.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 2 stripes, 16 solids, 101.2ms
# Speed: 2.5ms preprocess, 101.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 45/700 : 6.4%
#
# 0: 640x384 (no detections), 133.6ms
# Speed: 2.5ms preprocess, 133.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 3 stripes, 16 solids, 101.4ms
# Speed: 2.2ms preprocess, 101.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 46/700 : 6.6%
#
# 0: 640x384 (no detections), 130.3ms
# Speed: 2.6ms preprocess, 130.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 3 stripes, 16 solids, 104.0ms
# Speed: 2.2ms preprocess, 104.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
# 47/700 : 6.7%
#
# 0: 640x384 (no detections), 134.2ms
# Speed: 3.3ms preprocess, 134.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 4 stripes, 16 solids, 101.8ms
# Speed: 2.4ms preprocess, 101.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 48/700 : 6.9%
#
# 0: 640x384 (no detections), 131.8ms
# Speed: 2.4ms preprocess, 131.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 5 stripes, 17 solids, 100.5ms
# Speed: 3.0ms preprocess, 100.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 49/700 : 7.0%
#
# 0: 640x384 (no detections), 145.9ms
# Speed: 2.6ms preprocess, 145.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 2 stripes, 13 solids, 100.9ms
# Speed: 2.5ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 50/700 : 7.1%
#
# 0: 640x384 (no detections), 132.3ms
# Speed: 2.4ms preprocess, 132.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 3 stripes, 15 solids, 105.6ms
# Speed: 2.4ms preprocess, 105.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# 51/700 : 7.3%
#
# 0: 640x384 1 table_play_area, 132.5ms
# Speed: 2.3ms preprocess, 132.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 2 stripes, 9 solids, 100.0ms
# Speed: 2.7ms preprocess, 100.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 52/700 : 7.4%
#
# 0: 640x384 1 table_play_area, 131.7ms
# Speed: 2.3ms preprocess, 131.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 9 solids, 103.6ms
# Speed: 2.2ms preprocess, 103.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 53/700 : 7.6%
#
# 0: 640x384 (no detections), 134.8ms
# Speed: 2.4ms preprocess, 134.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 3 stripes, 14 solids, 101.0ms
# Speed: 2.4ms preprocess, 101.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 54/700 : 7.7%
#
# 0: 640x384 (no detections), 135.3ms
# Speed: 2.4ms preprocess, 135.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 4 stripes, 13 solids, 129.3ms
# Speed: 36.0ms preprocess, 129.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 55/700 : 7.9%
#
# 0: 640x384 (no detections), 180.1ms
# Speed: 3.3ms preprocess, 180.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 3 stripes, 13 solids, 129.3ms
# Speed: 4.1ms preprocess, 129.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 56/700 : 8.0%
#
# 0: 640x384 (no detections), 131.2ms
# Speed: 2.3ms preprocess, 131.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 4 stripes, 13 solids, 149.4ms
# Speed: 2.6ms preprocess, 149.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 57/700 : 8.1%
#
# 0: 640x384 (no detections), 140.5ms
# Speed: 3.2ms preprocess, 140.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 13 solids, 107.8ms
# Speed: 2.6ms preprocess, 107.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 58/700 : 8.3%
#
# 0: 640x384 (no detections), 134.2ms
# Speed: 2.3ms preprocess, 134.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 2 stripes, 14 solids, 105.4ms
# Speed: 2.6ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 59/700 : 8.4%
#
# 0: 640x384 (no detections), 134.1ms
# Speed: 2.4ms preprocess, 134.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 17 solids, 102.6ms
# Speed: 2.6ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 60/700 : 8.6%
#
# 0: 640x384 (no detections), 138.8ms
# Speed: 2.3ms preprocess, 138.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 5 stripes, 17 solids, 100.8ms
# Speed: 2.6ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 61/700 : 8.7%
#
# 0: 640x384 1 table_play_area, 131.3ms
# Speed: 2.4ms preprocess, 131.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 1 stripe, 9 solids, 99.5ms
# Speed: 2.3ms preprocess, 99.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 62/700 : 8.9%
#
# 0: 640x384 1 table_play_area, 131.5ms
# Speed: 2.6ms preprocess, 131.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 1 stripe, 10 solids, 103.3ms
# Speed: 2.3ms preprocess, 103.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# 63/700 : 9.0%
#
# 0: 640x384 1 table_play_area, 135.5ms
# Speed: 2.2ms preprocess, 135.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 10 solids, 99.7ms
# Speed: 2.6ms preprocess, 99.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 64/700 : 9.1%
#
# 0: 640x384 1 table_play_area, 133.1ms
# Speed: 2.5ms preprocess, 133.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 3 stripes, 15 solids, 98.5ms
# Speed: 2.4ms preprocess, 98.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 65/700 : 9.3%
#
# 0: 640x384 1 table_play_area, 176.2ms
# Speed: 2.3ms preprocess, 176.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 12 solids, 105.2ms
# Speed: 2.5ms preprocess, 105.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 66/700 : 9.4%
#
# 0: 640x384 1 table_play_area, 134.8ms
# Speed: 2.1ms preprocess, 134.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 2 stripes, 12 solids, 101.2ms
# Speed: 2.7ms preprocess, 101.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 67/700 : 9.6%
#
# 0: 640x384 1 table_play_area, 139.2ms
# Speed: 3.1ms preprocess, 139.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 12 solids, 100.3ms
# Speed: 2.5ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 68/700 : 9.7%
#
# 0: 640x384 1 table_play_area, 130.5ms
# Speed: 2.9ms preprocess, 130.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 1 stripe, 13 solids, 99.4ms
# Speed: 2.4ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 69/700 : 9.9%
#
# 0: 640x384 1 table_play_area, 132.2ms
# Speed: 2.9ms preprocess, 132.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 8_balls, 1 stripe, 14 solids, 142.6ms
# Speed: 2.3ms preprocess, 142.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 70/700 : 10.0%
#
# 0: 640x384 1 table_play_area, 148.5ms
# Speed: 7.9ms preprocess, 148.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 1 stripe, 13 solids, 108.1ms
# Speed: 2.4ms preprocess, 108.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# 71/700 : 10.1%
#
# 0: 640x384 1 table_play_area, 190.8ms
# Speed: 2.1ms preprocess, 190.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 1 stripe, 14 solids, 109.3ms
# Speed: 2.7ms preprocess, 109.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 72/700 : 10.3%
#
# 0: 640x384 1 table_play_area, 153.6ms
# Speed: 3.2ms preprocess, 153.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 15 solids, 107.2ms
# Speed: 2.2ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 73/700 : 10.4%
#
# 0: 640x384 1 table_play_area, 153.1ms
# Speed: 2.7ms preprocess, 153.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 2 stripes, 14 solids, 107.3ms
# Speed: 2.4ms preprocess, 107.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 74/700 : 10.6%
#
# 0: 640x384 1 table_play_area, 136.0ms
# Speed: 2.4ms preprocess, 136.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 12 solids, 113.4ms
# Speed: 53.3ms preprocess, 113.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 75/700 : 10.7%
#
# 0: 640x384 1 table_play_area, 138.6ms
# Speed: 2.4ms preprocess, 138.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 1 stripe, 14 solids, 104.9ms
# Speed: 2.5ms preprocess, 104.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 76/700 : 10.9%
#
# 0: 640x384 1 table_play_area, 139.3ms
# Speed: 2.2ms preprocess, 139.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 2 stripes, 13 solids, 107.6ms
# Speed: 3.0ms preprocess, 107.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 77/700 : 11.0%
#
# 0: 640x384 1 table_play_area, 136.1ms
# Speed: 2.3ms preprocess, 136.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 1 stripe, 12 solids, 103.0ms
# Speed: 2.5ms preprocess, 103.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 78/700 : 11.1%
#
# 0: 640x384 1 table_play_area, 138.7ms
# Speed: 2.7ms preprocess, 138.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 1 stripe, 11 solids, 104.6ms
# Speed: 2.8ms preprocess, 104.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 79/700 : 11.3%
#
# 0: 640x384 1 table_play_area, 138.7ms
# Speed: 2.3ms preprocess, 138.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 1 stripe, 12 solids, 113.7ms
# Speed: 2.4ms preprocess, 113.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 80/700 : 11.4%
#
# 0: 640x384 1 table_play_area, 206.4ms
# Speed: 2.3ms preprocess, 206.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 3 stripes, 8 solids, 105.0ms
# Speed: 2.5ms preprocess, 105.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 81/700 : 11.6%
#
# 0: 640x384 1 table_play_area, 141.4ms
# Speed: 2.6ms preprocess, 141.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 4 stripes, 12 solids, 103.9ms
# Speed: 2.6ms preprocess, 103.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 82/700 : 11.7%
#
# 0: 640x384 1 table_play_area, 136.7ms
# Speed: 2.6ms preprocess, 136.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 3 stripes, 14 solids, 104.5ms
# Speed: 2.5ms preprocess, 104.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 83/700 : 11.9%
#
# 0: 640x384 1 table_play_area, 141.0ms
# Speed: 2.5ms preprocess, 141.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 2 stripes, 14 solids, 106.9ms
# Speed: 2.5ms preprocess, 106.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 84/700 : 12.0%
#
# 0: 640x384 1 table_play_area, 136.7ms
# Speed: 2.1ms preprocess, 136.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 12 solids, 112.9ms
# Speed: 3.2ms preprocess, 112.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 85/700 : 12.1%
#
# 0: 640x384 1 table_play_area, 165.1ms
# Speed: 3.0ms preprocess, 165.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 4 stripes, 11 solids, 148.7ms
# Speed: 3.4ms preprocess, 148.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 86/700 : 12.3%
#
# 0: 640x384 1 table_play_area, 142.7ms
# Speed: 3.0ms preprocess, 142.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 4 stripes, 11 solids, 103.2ms
# Speed: 3.3ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 87/700 : 12.4%
#
# 0: 640x384 1 table_play_area, 136.3ms
# Speed: 2.3ms preprocess, 136.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 4 stripes, 11 solids, 103.7ms
# Speed: 2.2ms preprocess, 103.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# 88/700 : 12.6%
#
# 0: 640x384 1 table_play_area, 147.0ms
# Speed: 2.7ms preprocess, 147.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 4 stripes, 10 solids, 119.1ms
# Speed: 3.6ms preprocess, 119.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 89/700 : 12.7%
#
# 0: 640x384 1 table_play_area, 157.1ms
# Speed: 2.5ms preprocess, 157.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 2 stripes, 12 solids, 104.9ms
# Speed: 2.8ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 90/700 : 12.9%
#
# 0: 640x384 1 table_play_area, 195.7ms
# Speed: 2.3ms preprocess, 195.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 3 stripes, 14 solids, 105.6ms
# Speed: 2.2ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 91/700 : 13.0%
#
# 0: 640x384 1 table_play_area, 232.2ms
# Speed: 2.5ms preprocess, 232.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 4 stripes, 13 solids, 128.9ms
# Speed: 3.1ms preprocess, 128.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 92/700 : 13.1%
#
# 0: 640x384 1 table_play_area, 164.6ms
# Speed: 3.1ms preprocess, 164.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 3 stripes, 13 solids, 113.3ms
# Speed: 2.9ms preprocess, 113.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 93/700 : 13.3%
#
# 0: 640x384 1 table_play_area, 135.0ms
# Speed: 2.7ms preprocess, 135.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 8_balls, 3 stripes, 12 solids, 104.3ms
# Speed: 2.4ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 94/700 : 13.4%
#
# 0: 640x384 1 table_play_area, 199.1ms
# Speed: 2.3ms preprocess, 199.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 3 stripes, 13 solids, 103.1ms
# Speed: 2.2ms preprocess, 103.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 95/700 : 13.6%
#
# 0: 640x384 1 table_play_area, 141.8ms
# Speed: 2.7ms preprocess, 141.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 3 stripes, 9 solids, 103.7ms
# Speed: 2.8ms preprocess, 103.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 96/700 : 13.7%
#
# 0: 640x384 1 table_play_area, 189.9ms
# Speed: 3.4ms preprocess, 189.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 3 stripes, 10 solids, 136.8ms
# Speed: 3.5ms preprocess, 136.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 97/700 : 13.9%
#
# 0: 640x384 1 table_play_area, 152.5ms
# Speed: 2.5ms preprocess, 152.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 5 stripes, 7 solids, 115.1ms
# Speed: 2.6ms preprocess, 115.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 98/700 : 14.0%
#
# 0: 640x384 1 table_play_area, 145.9ms
# Speed: 2.3ms preprocess, 145.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 4 stripes, 8 solids, 111.7ms
# Speed: 2.5ms preprocess, 111.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 99/700 : 14.1%
#
# 0: 640x384 1 table_play_area, 139.9ms
# Speed: 2.5ms preprocess, 139.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 2 stripes, 10 solids, 188.5ms
# Speed: 3.4ms preprocess, 188.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 100/700 : 14.3%
#
# 0: 640x384 1 table_play_area, 160.5ms
# Speed: 2.4ms preprocess, 160.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 2 stripes, 8 solids, 152.8ms
# Speed: 17.6ms preprocess, 152.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 101/700 : 14.4%
#
# 0: 640x384 1 table_play_area, 158.0ms
# Speed: 4.1ms preprocess, 158.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 8_balls, 5 stripes, 9 solids, 123.9ms
# Speed: 3.0ms preprocess, 123.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 102/700 : 14.6%
#
# 0: 640x384 1 table_play_area, 147.2ms
# Speed: 5.7ms preprocess, 147.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 4 stripes, 11 solids, 154.5ms
# Speed: 2.4ms preprocess, 154.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 103/700 : 14.7%
#
# 0: 640x384 1 table_play_area, 143.2ms
# Speed: 2.8ms preprocess, 143.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 3 stripes, 8 solids, 109.3ms
# Speed: 2.5ms preprocess, 109.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 104/700 : 14.9%
#
# 0: 640x384 1 table_play_area, 186.2ms
# Speed: 2.5ms preprocess, 186.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 2 stripes, 8 solids, 120.2ms
# Speed: 4.0ms preprocess, 120.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 105/700 : 15.0%
#
# 0: 640x384 1 table_play_area, 146.7ms
# Speed: 2.5ms preprocess, 146.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 9 solids, 116.0ms
# Speed: 2.6ms preprocess, 116.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 106/700 : 15.1%
#
# 0: 640x384 1 table_play_area, 183.7ms
# Speed: 2.3ms preprocess, 183.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 2 stripes, 10 solids, 148.2ms
# Speed: 5.3ms preprocess, 148.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 107/700 : 15.3%
#
# 0: 640x384 1 table_play_area, 137.7ms
# Speed: 2.6ms preprocess, 137.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 2 stripes, 12 solids, 106.9ms
# Speed: 3.4ms preprocess, 106.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 108/700 : 15.4%
#
# 0: 640x384 1 table_play_area, 138.9ms
# Speed: 2.8ms preprocess, 138.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 3 stripes, 12 solids, 132.9ms
# Speed: 37.9ms preprocess, 132.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 109/700 : 15.6%
#
# 0: 640x384 1 table_play_area, 143.7ms
# Speed: 2.3ms preprocess, 143.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 10 solids, 108.8ms
# Speed: 3.3ms preprocess, 108.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 110/700 : 15.7%
#
# 0: 640x384 1 table_play_area, 139.0ms
# Speed: 2.7ms preprocess, 139.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 10 solids, 143.9ms
# Speed: 2.9ms preprocess, 143.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 111/700 : 15.9%
#
# 0: 640x384 1 table_play_area, 152.4ms
# Speed: 3.0ms preprocess, 152.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 3 stripes, 12 solids, 116.2ms
# Speed: 2.8ms preprocess, 116.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 112/700 : 16.0%
#
# 0: 640x384 1 table_play_area, 142.8ms
# Speed: 3.4ms preprocess, 142.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 3 stripes, 11 solids, 110.2ms
# Speed: 2.7ms preprocess, 110.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 113/700 : 16.1%
#
# 0: 640x384 1 table_play_area, 196.3ms
# Speed: 2.6ms preprocess, 196.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 10 solids, 108.9ms
# Speed: 2.4ms preprocess, 108.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 114/700 : 16.3%
#
# 0: 640x384 1 table_play_area, 143.0ms
# Speed: 2.7ms preprocess, 143.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 4 stripes, 10 solids, 107.5ms
# Speed: 2.7ms preprocess, 107.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 115/700 : 16.4%
#
# 0: 640x384 1 table_play_area, 144.6ms
# Speed: 2.4ms preprocess, 144.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 3 stripes, 11 solids, 107.1ms
# Speed: 2.3ms preprocess, 107.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 116/700 : 16.6%
#
# 0: 640x384 1 table_play_area, 136.5ms
# Speed: 2.2ms preprocess, 136.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 1 stripe, 9 solids, 104.8ms
# Speed: 2.2ms preprocess, 104.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# 117/700 : 16.7%
#
# 0: 640x384 1 table_play_area, 142.8ms
# Speed: 2.7ms preprocess, 142.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 8_balls, 2 stripes, 9 solids, 113.3ms
# Speed: 3.2ms preprocess, 113.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 118/700 : 16.9%
#
# 0: 640x384 1 table_play_area, 206.7ms
# Speed: 2.7ms preprocess, 206.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 1 stripe, 11 solids, 109.7ms
# Speed: 2.2ms preprocess, 109.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 119/700 : 17.0%
#
# 0: 640x384 1 table_play_area, 141.5ms
# Speed: 2.4ms preprocess, 141.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 3 stripes, 10 solids, 105.8ms
# Speed: 2.3ms preprocess, 105.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 120/700 : 17.1%
#
# 0: 640x384 1 table_play_area, 139.0ms
# Speed: 2.3ms preprocess, 139.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 12 solids, 104.8ms
# Speed: 2.9ms preprocess, 104.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 121/700 : 17.3%
#
# 0: 640x384 1 table_play_area, 139.5ms
# Speed: 2.3ms preprocess, 139.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 13 solids, 107.9ms
# Speed: 2.3ms preprocess, 107.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 122/700 : 17.4%
#
# 0: 640x384 1 table_play_area, 140.8ms
# Speed: 2.6ms preprocess, 140.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 11 solids, 102.6ms
# Speed: 2.3ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 123/700 : 17.6%
#
# 0: 640x384 1 table_play_area, 146.0ms
# Speed: 38.3ms preprocess, 146.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 11 solids, 105.2ms
# Speed: 2.8ms preprocess, 105.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 124/700 : 17.7%
#
# 0: 640x384 1 table_play_area, 137.4ms
# Speed: 2.4ms preprocess, 137.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 1 stripe, 12 solids, 105.6ms
# Speed: 3.0ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 125/700 : 17.9%
#
# 0: 640x384 1 table_play_area, 141.7ms
# Speed: 2.4ms preprocess, 141.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 10 solids, 105.4ms
# Speed: 2.4ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 126/700 : 18.0%
#
# 0: 640x384 1 table_play_area, 137.3ms
# Speed: 2.5ms preprocess, 137.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 1 stripe, 9 solids, 108.3ms
# Speed: 2.5ms preprocess, 108.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 127/700 : 18.1%
#
# 0: 640x384 1 table_play_area, 138.5ms
# Speed: 2.3ms preprocess, 138.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 1 stripe, 10 solids, 174.8ms
# Speed: 2.8ms preprocess, 174.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 128/700 : 18.3%
#
# 0: 640x384 1 table_play_area, 157.2ms
# Speed: 2.5ms preprocess, 157.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 8 solids, 119.5ms
# Speed: 2.5ms preprocess, 119.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 129/700 : 18.4%
#
# 0: 640x384 1 table_play_area, 141.4ms
# Speed: 2.2ms preprocess, 141.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 3 stripes, 10 solids, 104.3ms
# Speed: 3.0ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 130/700 : 18.6%
#
# 0: 640x384 1 table_play_area, 136.9ms
# Speed: 2.4ms preprocess, 136.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 3 stripes, 10 solids, 105.8ms
# Speed: 2.3ms preprocess, 105.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 131/700 : 18.7%
#
# 0: 640x384 1 table_play_area, 151.0ms
# Speed: 2.4ms preprocess, 151.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 1 stripe, 8 solids, 106.0ms
# Speed: 2.5ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 132/700 : 18.9%
#
# 0: 640x384 1 table_play_area, 138.4ms
# Speed: 2.9ms preprocess, 138.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 9 solids, 161.8ms
# Speed: 2.4ms preprocess, 161.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 133/700 : 19.0%
#
# 0: 640x384 1 table_play_area, 134.3ms
# Speed: 3.0ms preprocess, 134.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 9 solids, 103.9ms
# Speed: 2.3ms preprocess, 103.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 134/700 : 19.1%
#
# 0: 640x384 1 table_play_area, 138.7ms
# Speed: 2.3ms preprocess, 138.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 11 solids, 173.6ms
# Speed: 8.0ms preprocess, 173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 135/700 : 19.3%
#
# 0: 640x384 1 table_play_area, 141.1ms
# Speed: 2.5ms preprocess, 141.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 9 solids, 106.2ms
# Speed: 2.5ms preprocess, 106.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 136/700 : 19.4%
#
# 0: 640x384 1 table_play_area, 137.3ms
# Speed: 2.5ms preprocess, 137.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 1 stripe, 8 solids, 106.0ms
# Speed: 2.5ms preprocess, 106.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 137/700 : 19.6%
#
# 0: 640x384 1 table_play_area, 193.4ms
# Speed: 2.3ms preprocess, 193.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 8 solids, 106.8ms
# Speed: 2.6ms preprocess, 106.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 138/700 : 19.7%
#
# 0: 640x384 1 table_play_area, 138.7ms
# Speed: 2.9ms preprocess, 138.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 9 solids, 107.2ms
# Speed: 2.8ms preprocess, 107.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 139/700 : 19.9%
#
# 0: 640x384 1 table_play_area, 139.1ms
# Speed: 2.6ms preprocess, 139.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 3 stripes, 9 solids, 105.6ms
# Speed: 2.5ms preprocess, 105.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 140/700 : 20.0%
#
# 0: 640x384 1 table_play_area, 136.4ms
# Speed: 2.4ms preprocess, 136.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 8 solids, 107.2ms
# Speed: 2.2ms preprocess, 107.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 141/700 : 20.1%
#
# 0: 640x384 1 table_play_area, 139.6ms
# Speed: 2.3ms preprocess, 139.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 2 stripes, 8 solids, 164.4ms
# Speed: 3.2ms preprocess, 164.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 142/700 : 20.3%
#
# 0: 640x384 1 table_play_area, 133.0ms
# Speed: 3.1ms preprocess, 133.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 3 stripes, 10 solids, 104.6ms
# Speed: 2.4ms preprocess, 104.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 143/700 : 20.4%
#
# 0: 640x384 1 table_play_area, 159.6ms
# Speed: 2.8ms preprocess, 159.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 11 solids, 107.9ms
# Speed: 2.7ms preprocess, 107.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 144/700 : 20.6%
#
# 0: 640x384 1 table_play_area, 139.8ms
# Speed: 2.5ms preprocess, 139.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 8_balls, 2 stripes, 13 solids, 106.1ms
# Speed: 4.3ms preprocess, 106.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 145/700 : 20.7%
#
# 0: 640x384 1 table_play_area, 137.7ms
# Speed: 2.6ms preprocess, 137.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 11 solids, 104.4ms
# Speed: 3.8ms preprocess, 104.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 146/700 : 20.9%
#
# 0: 640x384 1 table_play_area, 139.0ms
# Speed: 2.3ms preprocess, 139.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 11 solids, 161.1ms
# Speed: 2.1ms preprocess, 161.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 147/700 : 21.0%
#
# 0: 640x384 1 table_play_area, 141.4ms
# Speed: 3.3ms preprocess, 141.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 8_balls, 1 stripe, 7 solids, 104.3ms
# Speed: 2.5ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 148/700 : 21.1%
#
# 0: 640x384 1 table_play_area, 136.9ms
# Speed: 2.5ms preprocess, 136.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 3 stripes, 8 solids, 107.7ms
# Speed: 2.4ms preprocess, 107.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 149/700 : 21.3%
#
# 0: 640x384 1 table_play_area, 136.6ms
# Speed: 2.4ms preprocess, 136.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 3 stripes, 11 solids, 109.6ms
# Speed: 2.5ms preprocess, 109.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 150/700 : 21.4%
#
# 0: 640x384 1 table_play_area, 138.7ms
# Speed: 2.4ms preprocess, 138.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 8_balls, 3 stripes, 11 solids, 104.5ms
# Speed: 2.4ms preprocess, 104.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 151/700 : 21.6%
#
# 0: 640x384 1 table_play_area, 193.6ms
# Speed: 2.4ms preprocess, 193.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 11 solids, 105.2ms
# Speed: 2.5ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 152/700 : 21.7%
#
# 0: 640x384 1 table_play_area, 138.3ms
# Speed: 2.7ms preprocess, 138.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 13 solids, 104.5ms
# Speed: 2.5ms preprocess, 104.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 153/700 : 21.9%
#
# 0: 640x384 1 table_play_area, 137.9ms
# Speed: 2.4ms preprocess, 137.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 1 stripe, 10 solids, 107.7ms
# Speed: 2.9ms preprocess, 107.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 154/700 : 22.0%
#
# 0: 640x384 1 table_play_area, 138.2ms
# Speed: 2.4ms preprocess, 138.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 11 solids, 121.1ms
# Speed: 2.4ms preprocess, 121.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 155/700 : 22.1%
#
# 0: 640x384 1 table_play_area, 137.8ms
# Speed: 2.4ms preprocess, 137.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 8_balls, 3 stripes, 10 solids, 104.4ms
# Speed: 2.9ms preprocess, 104.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 156/700 : 22.3%
#
# 0: 640x384 1 table_play_area, 146.4ms
# Speed: 56.1ms preprocess, 146.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 11 8_balls, 2 stripes, 12 solids, 117.0ms
# Speed: 2.6ms preprocess, 117.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 157/700 : 22.4%
#
# 0: 640x384 1 table_play_area, 151.5ms
# Speed: 2.5ms preprocess, 151.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 8_balls, 2 stripes, 11 solids, 112.9ms
# Speed: 2.8ms preprocess, 112.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 158/700 : 22.6%
#
# 0: 640x384 1 table_play_area, 138.9ms
# Speed: 2.3ms preprocess, 138.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 10 8_balls, 2 stripes, 10 solids, 164.7ms
# Speed: 3.2ms preprocess, 164.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 159/700 : 22.7%
#
# 0: 640x384 1 table_play_area, 150.8ms
# Speed: 2.8ms preprocess, 150.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 8_balls, 2 stripes, 12 solids, 119.7ms
# Speed: 2.2ms preprocess, 119.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 160/700 : 22.9%
#
# 0: 640x384 1 table_play_area, 152.3ms
# Speed: 2.4ms preprocess, 152.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 12 8_balls, 3 stripes, 11 solids, 104.7ms
# Speed: 3.3ms preprocess, 104.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 161/700 : 23.0%
# ✅ Prediction video saved: video_output/tes_with_preds.mp4

# %% [markdown]
# ### Mapping a Video (deprecated)

# %%
def detect_table_and_map_balls_video(input_video_path, output_video_path, max_frames=1000):
    cap = cv2.VideoCapture(input_video_path)
    if not cap.isOpened():
        print(f"Error: Cannot open video {input_video_path}")
        return

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_to_process = min(total_frames, max_frames)

    out = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width * 2, height))

    frame_idx = 0
    while frame_idx < frames_to_process:
        ret, frame = cap.read()
        if not ret:
            break

        img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # --- 1. Table detection ---
        table_results = table_model(frame)[0]
        if not table_results.masks:
            out.write(np.hstack((frame, frame)))
            frame_idx += 1
            continue

        mask = table_results.masks[0].data[0].cpu().numpy()
        mask_resized = cv2.resize(mask, (width, height))

        contours, _ = cv2.findContours((mask * 255).astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contour = max(contours, key=cv2.contourArea)
        epsilon = 0.05 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        if len(approx) != 4:
            out.write(np.hstack((frame, frame)))
            frame_idx += 1
            continue

        src_pts_raw = np.array([pt[0] for pt in approx], dtype=np.float32)
        src_pts = order_points_stable(src_pts_raw)
        
        dst_pts, dst_width, dst_height = compute_dst_pts_strict(src_pts)
        H, _ = cv2.findHomography(src_pts, dst_pts)

        # --- 2. Ball detection ---
        ball_results = ball_model(frame)[0]
        mapped_positions = []
        ball_labels = []

        for box in ball_results.boxes:
            x_c = box.xywh[0][0].item()
            y_c = box.xywh[0][1].item()
            x_int = int(np.clip(x_c, 0, width - 1))
            y_int = int(np.clip(y_c, 0, height - 1))

            if mask_resized[y_int, x_int] < 0.5:
                continue

            pt = np.array([[[x_c, y_c]]], dtype=np.float32)
            dst = cv2.perspectiveTransform(pt, H)[0][0]
            if 0 <= dst[0] <= dst_width and 0 <= dst[1] <= dst_height:
                mapped_positions.append(dst)
                ball_labels.append(int(box.cls[0].item()))

        # --- 3. Visualization ---
        # A. Original view
        vis_left = img_rgb.copy()
        for box in ball_results.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cls = int(box.cls[0].item())
            conf = float(box.conf[0])
            cv2.rectangle(vis_left, (x1, y1), (x2, y2), (255, 0, 0), 2)
            cv2.putText(vis_left, f"{cls} ({conf:.2f})", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

        # B. 2D top-down view
        vis_right = np.ones((dst_height, dst_width, 3), dtype=np.uint8) * 30
        for (x, y), label in zip(mapped_positions, ball_labels):
            y_flipped = dst_height - int(y)
            cv2.circle(vis_right, (int(x), y_flipped), 10, (255, 255, 255), -1)
            cv2.putText(vis_right, str(label), (int(x), y_flipped - 15), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

        vis_left = cv2.cvtColor(vis_left, cv2.COLOR_RGB2BGR)
        vis_right = cv2.resize(vis_right, (width, height))
        combined = np.hstack((vis_left, vis_right))

        out.write(combined)
        frame_idx += 1
        print(f"{frame_idx}/{frames_to_process} : {(frame_idx/frames_to_process) *100}%")

    cap.release()
    out.release()
    print(f"✅ Video saved to {output_video_path}")

# %%
detect_table_and_map_balls_video("video_input/vid6.mp4", "video_output/vid6_out.mp4")
