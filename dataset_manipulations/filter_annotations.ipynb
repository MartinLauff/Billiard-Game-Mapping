# %% [markdown]
# ## Convert Annotations to Train/Val/Test folders

# %%
import os

# %%
# Paths
annotation_file = "corner_mapped.txt"
train_labels_dir = "corner_dataset/labels/train"
val_labels_dir = "corner_dataset/labels/val"
test_labels_dir = "corner_dataset/labels/test"

# %%
# Create directories
os.makedirs(train_labels_dir, exist_ok=True)
os.makedirs(val_labels_dir, exist_ok=True)
os.makedirs(test_labels_dir, exist_ok=True)

# %%
# Read annotations and create separate class_id files
with open(annotation_file, "r") as file:
    lines = file.readlines()

for line in lines:
    parts = line.strip().split()
    
    # Extract filename, class_id, and bounding box data
    image_name = parts[0]   # First column is the filename
    class_id = parts[1]        # Second column is the class_id
    bbox_data = parts[2:]   # Remaining columns are bbox values (x_center, y_center, width, height)

    # Determine correct folder based on image location
    if os.path.exists(f"corner_dataset/images/train/{image_name}"):
        label_path = os.path.join(train_labels_dir, image_name.replace(".png", ".txt"))
    elif os.path.exists(f"corner_dataset/images/val/{image_name}"):
        label_path = os.path.join(val_labels_dir, image_name.replace(".png", ".txt"))
    elif os.path.exists(f"corner_dataset/images/test/{image_name}"):
        label_path = os.path.join(test_labels_dir, image_name.replace(".png", ".txt"))
    else:
        continue  # Skip if the image isn't in train, val, or test

    # Write YOLO label file (Format: class x_center y_center width height)
    with open(label_path, "a") as label_file:
        label_file.write(f"{class_id} " + " ".join(bbox_data) + "\n")

print("Annotations successfully converted to YOLO format with labels.")
# Out:
# Annotations successfully converted to YOLO format with labels.

# %%
all_images = [f for f in os.listdir("corner_dataset") if f.endswith((".txt"))]

# %%
import os
import shutil

# Define your dataset root
dataset_root = "corner_dataset"

# Source of the .txt segmentation files
source_label_folder = os.path.join(dataset_root, "labels_seg")

# Define your image + target label folders
splits = ["train", "val", "test"]
for split in splits:
    image_folder = os.path.join(dataset_root, "images", split)
    label_folder = os.path.join(dataset_root, "labels", split)
    os.makedirs(label_folder, exist_ok=True)

    # Loop through all images in this split
    for img_file in os.listdir(image_folder):
        if img_file.lower().endswith(".png"):
            txt_file = img_file.rsplit(".", 1)[0] + ".txt"
            src_txt_path = os.path.join(source_label_folder, txt_file)
            dst_txt_path = os.path.join(label_folder, txt_file)

            if os.path.exists(src_txt_path):
                shutil.move(src_txt_path, dst_txt_path)
                print(f"✅ Moved: {txt_file} → {split}/")
            else:
                print(f"⚠️ Missing label for: {img_file}")
# Out:
# ✅ Moved: table_0.txt → train/
# ✅ Moved: table_100.txt → train/
# ✅ Moved: table_1000.txt → train/
# ✅ Moved: table_1001.txt → train/
# ✅ Moved: table_1003.txt → train/
# ✅ Moved: table_1004.txt → train/
# ✅ Moved: table_1007.txt → train/
# ✅ Moved: table_101.txt → train/
# ✅ Moved: table_1011.txt → train/
# ✅ Moved: table_1013.txt → train/
# ✅ Moved: table_1015.txt → train/
# ✅ Moved: table_1016.txt → train/
# ✅ Moved: table_1017.txt → train/
# ✅ Moved: table_1019.txt → train/
# ✅ Moved: table_1020.txt → train/
# ✅ Moved: table_1021.txt → train/
# ✅ Moved: table_1024.txt → train/
# ✅ Moved: table_1027.txt → train/
# ✅ Moved: table_1029.txt → train/
# ✅ Moved: table_103.txt → train/
# ✅ Moved: table_1030.txt → train/
# ✅ Moved: table_1032.txt → train/
# ✅ Moved: table_1033.txt → train/
# ✅ Moved: table_1034.txt → train/
# ✅ Moved: table_1035.txt → train/
# ✅ Moved: table_1036.txt → train/
# ✅ Moved: table_1039.txt → train/
# ✅ Moved: table_104.txt → train/
# ✅ Moved: table_1041.txt → train/
# ✅ Moved: table_1048.txt → train/
# ✅ Moved: table_1050.txt → train/
# ✅ Moved: table_1058.txt → train/
# ✅ Moved: table_1059.txt → train/
# ✅ Moved: table_1060.txt → train/
# ✅ Moved: table_1063.txt → train/
# ✅ Moved: table_1070.txt → train/
# ✅ Moved: table_1075.txt → train/
# ✅ Moved: table_1080.txt → train/
# ✅ Moved: table_1081.txt → train/
# ✅ Moved: table_1083.txt → train/
# ✅ Moved: table_1086.txt → train/
# ✅ Moved: table_109.txt → train/
# ✅ Moved: table_1090.txt → train/
# ✅ Moved: table_1092.txt → train/
# ✅ Moved: table_1098.txt → train/
# ✅ Moved: table_11.txt → train/
# ✅ Moved: table_110.txt → train/
# ✅ Moved: table_1102.txt → train/
# ✅ Moved: table_1105.txt → train/
# ✅ Moved: table_1106.txt → train/
# ✅ Moved: table_1108.txt → train/
# ✅ Moved: table_1109.txt → train/
# ✅ Moved: table_1113.txt → train/
# ✅ Moved: table_1115.txt → train/
# ✅ Moved: table_1116.txt → train/
# ✅ Moved: table_112.txt → train/
# ✅ Moved: table_1120.txt → train/
# ✅ Moved: table_1123.txt → train/
# ✅ Moved: table_1129.txt → train/
# ✅ Moved: table_1137.txt → train/
# ✅ Moved: table_1141.txt → train/
# ✅ Moved: table_1143.txt → train/
# ✅ Moved: table_1145.txt → train/
# ✅ Moved: table_1146.txt → train/
# ✅ Moved: table_1147.txt → train/
# ✅ Moved: table_1148.txt → train/
# ✅ Moved: table_1150.txt → train/
# ✅ Moved: table_1153.txt → train/
# ✅ Moved: table_1157.txt → train/
# ✅ Moved: table_1158.txt → train/
# ✅ Moved: table_1160.txt → train/
# ✅ Moved: table_1161.txt → train/
# ✅ Moved: table_1162.txt → train/
# ✅ Moved: table_1167.txt → train/
# ✅ Moved: table_117.txt → train/
# ✅ Moved: table_1172.txt → train/
# ✅ Moved: table_1173.txt → train/
# ✅ Moved: table_1174.txt → train/
# ✅ Moved: table_1175.txt → train/
# ✅ Moved: table_1177.txt → train/
# ✅ Moved: table_1180.txt → train/
# ✅ Moved: table_1182.txt → train/
# ✅ Moved: table_1187.txt → train/
# ✅ Moved: table_1189.txt → train/
# ✅ Moved: table_1191.txt → train/
# ✅ Moved: table_1195.txt → train/
# ✅ Moved: table_1196.txt → train/
# ✅ Moved: table_1198.txt → train/
# ✅ Moved: table_120.txt → train/
# ✅ Moved: table_1200.txt → train/
# ✅ Moved: table_1202.txt → train/
# ✅ Moved: table_1203.txt → train/
# ✅ Moved: table_1206.txt → train/
# ✅ Moved: table_1207.txt → train/
# ✅ Moved: table_1211.txt → train/
# ✅ Moved: table_1212.txt → train/
# ✅ Moved: table_1214.txt → train/
# ✅ Moved: table_1215.txt → train/
# ✅ Moved: table_1217.txt → train/
# ✅ Moved: table_122.txt → train/
# ✅ Moved: table_1220.txt → train/
# ✅ Moved: table_1224.txt → train/
# ✅ Moved: table_1225.txt → train/
# ✅ Moved: table_1226.txt → train/
# ✅ Moved: table_1231.txt → train/
# ✅ Moved: table_1235.txt → train/
# ✅ Moved: table_1236.txt → train/
# ✅ Moved: table_1238.txt → train/
# ✅ Moved: table_1239.txt → train/
# ✅ Moved: table_124.txt → train/
# ✅ Moved: table_1240.txt → train/
# ✅ Moved: table_1241.txt → train/
# ✅ Moved: table_1243.txt → train/
# ✅ Moved: table_1245.txt → train/
# ✅ Moved: table_1248.txt → train/
# ✅ Moved: table_1249.txt → train/
# ✅ Moved: table_1252.txt → train/
# ✅ Moved: table_1258.txt → train/
# ✅ Moved: table_126.txt → train/
# ✅ Moved: table_1263.txt → train/
# ✅ Moved: table_1264.txt → train/
# ✅ Moved: table_1266.txt → train/
# ✅ Moved: table_1268.txt → train/
# ✅ Moved: table_1275.txt → train/
# ✅ Moved: table_1276.txt → train/
# ✅ Moved: table_1277.txt → train/
# ✅ Moved: table_1279.txt → train/
# ✅ Moved: table_1282.txt → train/
# ✅ Moved: table_1285.txt → train/
# ✅ Moved: table_1287.txt → train/
# ✅ Moved: table_1289.txt → train/
# ✅ Moved: table_129.txt → train/
# ✅ Moved: table_1290.txt → train/
# ✅ Moved: table_1292.txt → train/
# ✅ Moved: table_1293.txt → train/
# ✅ Moved: table_1294.txt → train/
# ✅ Moved: table_130.txt → train/
# ✅ Moved: table_1303.txt → train/
# ✅ Moved: table_1304.txt → train/
# ✅ Moved: table_1309.txt → train/
# ✅ Moved: table_131.txt → train/
# ✅ Moved: table_1312.txt → train/
# ✅ Moved: table_1317.txt → train/
# ✅ Moved: table_1318.txt → train/
# ✅ Moved: table_1319.txt → train/
# ✅ Moved: table_1320.txt → train/
# ✅ Moved: table_1321.txt → train/
# ✅ Moved: table_1324.txt → train/
# ✅ Moved: table_1325.txt → train/
# ✅ Moved: table_1327.txt → train/
# ✅ Moved: table_1332.txt → train/
# ✅ Moved: table_1335.txt → train/
# ✅ Moved: table_1336.txt → train/
# ✅ Moved: table_1342.txt → train/
# ✅ Moved: table_1344.txt → train/
# ✅ Moved: table_1346.txt → train/
# ✅ Moved: table_1347.txt → train/
# ✅ Moved: table_1349.txt → train/
# ✅ Moved: table_135.txt → train/
# ✅ Moved: table_1350.txt → train/
# ✅ Moved: table_1352.txt → train/
# ✅ Moved: table_1355.txt → train/
# ✅ Moved: table_1359.txt → train/
# ✅ Moved: table_1362.txt → train/
# ✅ Moved: table_1363.txt → train/
# ✅ Moved: table_1366.txt → train/
# ✅ Moved: table_1367.txt → train/
# ✅ Moved: table_1368.txt → train/
# ✅ Moved: table_1369.txt → train/
# ✅ Moved: table_1371.txt → train/
# ✅ Moved: table_1374.txt → train/
# ✅ Moved: table_1375.txt → train/
# ✅ Moved: table_1378.txt → train/
# ✅ Moved: table_138.txt → train/
# ✅ Moved: table_1380.txt → train/
# ✅ Moved: table_1381.txt → train/
# ✅ Moved: table_1383.txt → train/
# ✅ Moved: table_1384.txt → train/
# ✅ Moved: table_1385.txt → train/
# ✅ Moved: table_1390.txt → train/
# ✅ Moved: table_1394.txt → train/
# ✅ Moved: table_1395.txt → train/
# ✅ Moved: table_1398.txt → train/
# ✅ Moved: table_140.txt → train/
# ✅ Moved: table_1400.txt → train/
# ✅ Moved: table_1401.txt → train/
# ✅ Moved: table_1405.txt → train/
# ✅ Moved: table_1409.txt → train/
# ✅ Moved: table_141.txt → train/
# ✅ Moved: table_1411.txt → train/
# ✅ Moved: table_1412.txt → train/
# ✅ Moved: table_1413.txt → train/
# ✅ Moved: table_1416.txt → train/
# ✅ Moved: table_1421.txt → train/
# ✅ Moved: table_1422.txt → train/
# ✅ Moved: table_1424.txt → train/
# ✅ Moved: table_1427.txt → train/
# ✅ Moved: table_1429.txt → train/
# ✅ Moved: table_1430.txt → train/
# ✅ Moved: table_1434.txt → train/
# ✅ Moved: table_1436.txt → train/
# ✅ Moved: table_1437.txt → train/
# ✅ Moved: table_1439.txt → train/
# ✅ Moved: table_144.txt → train/
# ✅ Moved: table_1440.txt → train/
# ✅ Moved: table_1442.txt → train/
# ✅ Moved: table_1443.txt → train/
# ✅ Moved: table_1444.txt → train/
# ✅ Moved: table_1445.txt → train/
# ✅ Moved: table_145.txt → train/
# ✅ Moved: table_1450.txt → train/
# ✅ Moved: table_1452.txt → train/
# ✅ Moved: table_1454.txt → train/
# ✅ Moved: table_1456.txt → train/
# ✅ Moved: table_1457.txt → train/
# ✅ Moved: table_1460.txt → train/
# ✅ Moved: table_1462.txt → train/
# ✅ Moved: table_1464.txt → train/
# ✅ Moved: table_1467.txt → train/
# ✅ Moved: table_1469.txt → train/
# ✅ Moved: table_1470.txt → train/
# ✅ Moved: table_1471.txt → train/
# ✅ Moved: table_1472.txt → train/
# ✅ Moved: table_1473.txt → train/
# ✅ Moved: table_1474.txt → train/
# ✅ Moved: table_1475.txt → train/
# ✅ Moved: table_1477.txt → train/
# ✅ Moved: table_1478.txt → train/
# ✅ Moved: table_148.txt → train/
# ✅ Moved: table_1484.txt → train/
# ✅ Moved: table_1487.txt → train/
# ✅ Moved: table_149.txt → train/
# ✅ Moved: table_1490.txt → train/
# ✅ Moved: table_1492.txt → train/
# ✅ Moved: table_1493.txt → train/
# ✅ Moved: table_1494.txt → train/
# ✅ Moved: table_1496.txt → train/
# ✅ Moved: table_1497.txt → train/
# ✅ Moved: table_1498.txt → train/
# ✅ Moved: table_1499.txt → train/
# ✅ Moved: table_150.txt → train/
# ✅ Moved: table_1500.txt → train/
# ✅ Moved: table_1502.txt → train/
# ✅ Moved: table_1505.txt → train/
# ✅ Moved: table_1507.txt → train/
# ✅ Moved: table_1508.txt → train/
# ✅ Moved: table_151.txt → train/
# ✅ Moved: table_1514.txt → train/
# ✅ Moved: table_1517.txt → train/
# ✅ Moved: table_1518.txt → train/
# ✅ Moved: table_152.txt → train/
# ✅ Moved: table_1521.txt → train/
# ✅ Moved: table_1523.txt → train/
# ✅ Moved: table_1528.txt → train/
# ✅ Moved: table_1530.txt → train/
# ✅ Moved: table_1533.txt → train/
# ✅ Moved: table_1537.txt → train/
# ✅ Moved: table_1538.txt → train/
# ✅ Moved: table_1539.txt → train/
# ✅ Moved: table_154.txt → train/
# ✅ Moved: table_1540.txt → train/
# ✅ Moved: table_1542.txt → train/
# ✅ Moved: table_1544.txt → train/
# ✅ Moved: table_1549.txt → train/
# ✅ Moved: table_1554.txt → train/
# ✅ Moved: table_1555.txt → train/
# ✅ Moved: table_1556.txt → train/
# ✅ Moved: table_1559.txt → train/
# ✅ Moved: table_156.txt → train/
# ✅ Moved: table_1563.txt → train/
# ✅ Moved: table_1564.txt → train/
# ✅ Moved: table_1569.txt → train/
# ✅ Moved: table_157.txt → train/
# ✅ Moved: table_1573.txt → train/
# ✅ Moved: table_1577.txt → train/
# ✅ Moved: table_1578.txt → train/
# ✅ Moved: table_1580.txt → train/
# ✅ Moved: table_1581.txt → train/
# ✅ Moved: table_1584.txt → train/
# ✅ Moved: table_1586.txt → train/
# ✅ Moved: table_1587.txt → train/
# ✅ Moved: table_1589.txt → train/
# ✅ Moved: table_1590.txt → train/
# ✅ Moved: table_1599.txt → train/
# ✅ Moved: table_1606.txt → train/
# ✅ Moved: table_1607.txt → train/
# ✅ Moved: table_1608.txt → train/
# ✅ Moved: table_161.txt → train/
# ✅ Moved: table_1610.txt → train/
# ✅ Moved: table_1611.txt → train/
# ✅ Moved: table_1615.txt → train/
# ✅ Moved: table_1617.txt → train/
# ✅ Moved: table_1620.txt → train/
# ✅ Moved: table_1625.txt → train/
# ✅ Moved: table_1627.txt → train/
# ✅ Moved: table_1628.txt → train/
# ✅ Moved: table_163.txt → train/
# ✅ Moved: table_1630.txt → train/
# ✅ Moved: table_1633.txt → train/
# ✅ Moved: table_1634.txt → train/
# ✅ Moved: table_1635.txt → train/
# ✅ Moved: table_1637.txt → train/
# ✅ Moved: table_1639.txt → train/
# ✅ Moved: table_164.txt → train/
# ✅ Moved: table_1643.txt → train/
# ✅ Moved: table_1645.txt → train/
# ✅ Moved: table_1647.txt → train/
# ✅ Moved: table_1648.txt → train/
# ✅ Moved: table_1649.txt → train/
# ✅ Moved: table_165.txt → train/
# ✅ Moved: table_1652.txt → train/
# ✅ Moved: table_1655.txt → train/
# ✅ Moved: table_1656.txt → train/
# ✅ Moved: table_1658.txt → train/
# ✅ Moved: table_1662.txt → train/
# ✅ Moved: table_1665.txt → train/
# ✅ Moved: table_1666.txt → train/
# ✅ Moved: table_1667.txt → train/
# ✅ Moved: table_1669.txt → train/
# ✅ Moved: table_1670.txt → train/
# ✅ Moved: table_1671.txt → train/
# ✅ Moved: table_1672.txt → train/
# ✅ Moved: table_1673.txt → train/
# ✅ Moved: table_1675.txt → train/
# ✅ Moved: table_1676.txt → train/
# ✅ Moved: table_1679.txt → train/
# ✅ Moved: table_168.txt → train/
# ✅ Moved: table_1680.txt → train/
# ✅ Moved: table_1681.txt → train/
# ✅ Moved: table_1682.txt → train/
# ✅ Moved: table_1683.txt → train/
# ✅ Moved: table_169.txt → train/
# ✅ Moved: table_1690.txt → train/
# ✅ Moved: table_1693.txt → train/
# ✅ Moved: table_1694.txt → train/
# ✅ Moved: table_1696.txt → train/
# ✅ Moved: table_17.txt → train/
# ✅ Moved: table_1700.txt → train/
# ✅ Moved: table_1702.txt → train/
# ✅ Moved: table_1703.txt → train/
# ✅ Moved: table_1706.txt → train/
# ✅ Moved: table_1707.txt → train/
# ✅ Moved: table_1708.txt → train/
# ✅ Moved: table_1709.txt → train/
# ✅ Moved: table_171.txt → train/
# ✅ Moved: table_1710.txt → train/
# ✅ Moved: table_1714.txt → train/
# ✅ Moved: table_172.txt → train/
# ✅ Moved: table_1720.txt → train/
# ✅ Moved: table_1722.txt → train/
# ✅ Moved: table_1724.txt → train/
# ✅ Moved: table_1725.txt → train/
# ✅ Moved: table_1728.txt → train/
# ✅ Moved: table_173.txt → train/
# ✅ Moved: table_1730.txt → train/
# ✅ Moved: table_1731.txt → train/
# ✅ Moved: table_1737.txt → train/
# ✅ Moved: table_174.txt → train/
# ✅ Moved: table_1745.txt → train/
# ✅ Moved: table_1748.txt → train/
# ✅ Moved: table_1749.txt → train/
# ✅ Moved: table_175.txt → train/
# ✅ Moved: table_1750.txt → train/
# ✅ Moved: table_1752.txt → train/
# ✅ Moved: table_1753.txt → train/
# ✅ Moved: table_1755.txt → train/
# ✅ Moved: table_1760.txt → train/
# ✅ Moved: table_1761.txt → train/
# ✅ Moved: table_1762.txt → train/
# ✅ Moved: table_1770.txt → train/
# ✅ Moved: table_1773.txt → train/
# ✅ Moved: table_1777.txt → train/
# ✅ Moved: table_1779.txt → train/
# ✅ Moved: table_178.txt → train/
# ✅ Moved: table_1780.txt → train/
# ✅ Moved: table_1783.txt → train/
# ✅ Moved: table_1786.txt → train/
# ✅ Moved: table_1787.txt → train/
# ✅ Moved: table_179.txt → train/
# ✅ Moved: table_1790.txt → train/
# ✅ Moved: table_1791.txt → train/
# ✅ Moved: table_1792.txt → train/
# ✅ Moved: table_1793.txt → train/
# ✅ Moved: table_1794.txt → train/
# ✅ Moved: table_1796.txt → train/
# ✅ Moved: table_1798.txt → train/
# ✅ Moved: table_180.txt → train/
# ✅ Moved: table_1800.txt → train/
# ✅ Moved: table_1802.txt → train/
# ✅ Moved: table_1803.txt → train/
# ✅ Moved: table_1804.txt → train/
# ✅ Moved: table_1807.txt → train/
# ✅ Moved: table_1808.txt → train/
# ✅ Moved: table_1809.txt → train/
# ✅ Moved: table_181.txt → train/
# ✅ Moved: table_1811.txt → train/
# ✅ Moved: table_1815.txt → train/
# ✅ Moved: table_1816.txt → train/
# ✅ Moved: table_182.txt → train/
# ✅ Moved: table_1820.txt → train/
# ✅ Moved: table_1822.txt → train/
# ✅ Moved: table_1827.txt → train/
# ✅ Moved: table_1828.txt → train/
# ✅ Moved: table_1831.txt → train/
# ✅ Moved: table_1832.txt → train/
# ✅ Moved: table_184.txt → train/
# ✅ Moved: table_1840.txt → train/
# ✅ Moved: table_1841.txt → train/
# ✅ Moved: table_1846.txt → train/
# ✅ Moved: table_1850.txt → train/
# ✅ Moved: table_1851.txt → train/
# ✅ Moved: table_1852.txt → train/
# ✅ Moved: table_1853.txt → train/
# ✅ Moved: table_1855.txt → train/
# ✅ Moved: table_1856.txt → train/
# ✅ Moved: table_1858.txt → train/
# ✅ Moved: table_1859.txt → train/
# ✅ Moved: table_1860.txt → train/
# ✅ Moved: table_1861.txt → train/
# ✅ Moved: table_1862.txt → train/
# ✅ Moved: table_1864.txt → train/
# ✅ Moved: table_1867.txt → train/
# ✅ Moved: table_187.txt → train/
# ✅ Moved: table_1871.txt → train/
# ✅ Moved: table_1873.txt → train/
# ✅ Moved: table_1879.txt → train/
# ✅ Moved: table_1880.txt → train/
# ✅ Moved: table_1881.txt → train/
# ✅ Moved: table_1885.txt → train/
# ✅ Moved: table_1890.txt → train/
# ✅ Moved: table_1891.txt → train/
# ✅ Moved: table_1894.txt → train/
# ✅ Moved: table_1896.txt → train/
# ✅ Moved: table_1897.txt → train/
# ✅ Moved: table_1901.txt → train/
# ✅ Moved: table_1903.txt → train/
# ✅ Moved: table_1905.txt → train/
# ✅ Moved: table_1909.txt → train/
# ✅ Moved: table_1913.txt → train/
# ✅ Moved: table_1917.txt → train/
# ✅ Moved: table_1921.txt → train/
# ✅ Moved: table_1922.txt → train/
# ✅ Moved: table_1923.txt → train/
# ✅ Moved: table_1927.txt → train/
# ✅ Moved: table_1929.txt → train/
# ✅ Moved: table_193.txt → train/
# ✅ Moved: table_1930.txt → train/
# ✅ Moved: table_1931.txt → train/
# ✅ Moved: table_1932.txt → train/
# ✅ Moved: table_1933.txt → train/
# ✅ Moved: table_1937.txt → train/
# ✅ Moved: table_1938.txt → train/
# ✅ Moved: table_1940.txt → train/
# ✅ Moved: table_1941.txt → train/
# ✅ Moved: table_1945.txt → train/
# ✅ Moved: table_1946.txt → train/
# ✅ Moved: table_1947.txt → train/
# ✅ Moved: table_1953.txt → train/
# ✅ Moved: table_1958.txt → train/
# ✅ Moved: table_196.txt → train/
# ✅ Moved: table_1964.txt → train/
# ✅ Moved: table_1968.txt → train/
# ✅ Moved: table_197.txt → train/
# ✅ Moved: table_1977.txt → train/
# ✅ Moved: table_198.txt → train/
# ✅ Moved: table_1981.txt → train/
# ✅ Moved: table_1983.txt → train/
# ✅ Moved: table_1984.txt → train/
# ✅ Moved: table_1985.txt → train/
# ✅ Moved: table_1987.txt → train/
# ✅ Moved: table_1990.txt → train/
# ✅ Moved: table_1991.txt → train/
# ✅ Moved: table_1992.txt → train/
# ✅ Moved: table_1993.txt → train/
# ✅ Moved: table_1997.txt → train/
# ✅ Moved: table_20.txt → train/
# ✅ Moved: table_2000.txt → train/
# ✅ Moved: table_2001.txt → train/
# ✅ Moved: table_2002.txt → train/
# ✅ Moved: table_2004.txt → train/
# ✅ Moved: table_2008.txt → train/
# ✅ Moved: table_2009.txt → train/
# ✅ Moved: table_201.txt → train/
# ✅ Moved: table_2015.txt → train/
# ✅ Moved: table_2019.txt → train/
# ✅ Moved: table_202.txt → train/
# ✅ Moved: table_2024.txt → train/
# ✅ Moved: table_2026.txt → train/
# ✅ Moved: table_2029.txt → train/
# ✅ Moved: table_203.txt → train/
# ✅ Moved: table_2030.txt → train/
# ✅ Moved: table_2032.txt → train/
# ✅ Moved: table_2033.txt → train/
# ✅ Moved: table_2034.txt → train/
# ✅ Moved: table_2036.txt → train/
# ✅ Moved: table_2039.txt → train/
# ✅ Moved: table_2040.txt → train/
# ✅ Moved: table_2042.txt → train/
# ✅ Moved: table_2043.txt → train/
# ✅ Moved: table_2044.txt → train/
# ✅ Moved: table_2049.txt → train/
# ✅ Moved: table_205.txt → train/
# ✅ Moved: table_2050.txt → train/
# ✅ Moved: table_2052.txt → train/
# ✅ Moved: table_2055.txt → train/
# ✅ Moved: table_2056.txt → train/
# ✅ Moved: table_2060.txt → train/
# ✅ Moved: table_2063.txt → train/
# ✅ Moved: table_2065.txt → train/
# ✅ Moved: table_2067.txt → train/
# ✅ Moved: table_2069.txt → train/
# ✅ Moved: table_2073.txt → train/
# ✅ Moved: table_2074.txt → train/
# ✅ Moved: table_2075.txt → train/
# ✅ Moved: table_2077.txt → train/
# ✅ Moved: table_2080.txt → train/
# ✅ Moved: table_2082.txt → train/
# ✅ Moved: table_2083.txt → train/
# ✅ Moved: table_2086.txt → train/
# ✅ Moved: table_2087.txt → train/
# ✅ Moved: table_209.txt → train/
# ✅ Moved: table_2092.txt → train/
# ✅ Moved: table_2094.txt → train/
# ✅ Moved: table_2096.txt → train/
# ✅ Moved: table_2098.txt → train/
# ✅ Moved: table_2106.txt → train/
# ✅ Moved: table_2108.txt → train/
# ✅ Moved: table_211.txt → train/
# ✅ Moved: table_2110.txt → train/
# ✅ Moved: table_2116.txt → train/
# ✅ Moved: table_2118.txt → train/
# ✅ Moved: table_212.txt → train/
# ✅ Moved: table_2120.txt → train/
# ✅ Moved: table_2121.txt → train/
# ✅ Moved: table_2125.txt → train/
# ✅ Moved: table_2126.txt → train/
# ✅ Moved: table_2127.txt → train/
# ✅ Moved: table_2128.txt → train/
# ✅ Moved: table_2129.txt → train/
# ✅ Moved: table_2130.txt → train/
# ✅ Moved: table_2136.txt → train/
# ✅ Moved: table_2148.txt → train/
# ✅ Moved: table_215.txt → train/
# ✅ Moved: table_2151.txt → train/
# ✅ Moved: table_2152.txt → train/
# ✅ Moved: table_2153.txt → train/
# ✅ Moved: table_2155.txt → train/
# ✅ Moved: table_2157.txt → train/
# ✅ Moved: table_2158.txt → train/
# ✅ Moved: table_2159.txt → train/
# ✅ Moved: table_2162.txt → train/
# ✅ Moved: table_2165.txt → train/
# ✅ Moved: table_2168.txt → train/
# ✅ Moved: table_2172.txt → train/
# ✅ Moved: table_2174.txt → train/
# ✅ Moved: table_2175.txt → train/
# ✅ Moved: table_2176.txt → train/
# ✅ Moved: table_2186.txt → train/
# ✅ Moved: table_2190.txt → train/
# ✅ Moved: table_2191.txt → train/
# ✅ Moved: table_2192.txt → train/
# ✅ Moved: table_2194.txt → train/
# ✅ Moved: table_2195.txt → train/
# ✅ Moved: table_2197.txt → train/
# ✅ Moved: table_2198.txt → train/
# ✅ Moved: table_22.txt → train/
# ✅ Moved: table_220.txt → train/
# ✅ Moved: table_2201.txt → train/
# ✅ Moved: table_2203.txt → train/
# ✅ Moved: table_2204.txt → train/
# ✅ Moved: table_2205.txt → train/
# ✅ Moved: table_2206.txt → train/
# ✅ Moved: table_2207.txt → train/
# ✅ Moved: table_2208.txt → train/
# ✅ Moved: table_221.txt → train/
# ✅ Moved: table_2211.txt → train/
# ✅ Moved: table_2212.txt → train/
# ✅ Moved: table_2215.txt → train/
# ✅ Moved: table_2217.txt → train/
# ✅ Moved: table_2218.txt → train/
# ✅ Moved: table_2222.txt → train/
# ✅ Moved: table_2225.txt → train/
# ✅ Moved: table_2228.txt → train/
# ✅ Moved: table_2229.txt → train/
# ✅ Moved: table_223.txt → train/
# ✅ Moved: table_2230.txt → train/
# ✅ Moved: table_2231.txt → train/
# ✅ Moved: table_2234.txt → train/
# ✅ Moved: table_2235.txt → train/
# ✅ Moved: table_2236.txt → train/
# ✅ Moved: table_2238.txt → train/
# ✅ Moved: table_2239.txt → train/
# ✅ Moved: table_224.txt → train/
# ✅ Moved: table_2241.txt → train/
# ✅ Moved: table_2242.txt → train/
# ✅ Moved: table_2246.txt → train/
# ✅ Moved: table_225.txt → train/
# ✅ Moved: table_2251.txt → train/
# ✅ Moved: table_2253.txt → train/
# ✅ Moved: table_2255.txt → train/
# ✅ Moved: table_2259.txt → train/
# ✅ Moved: table_2260.txt → train/
# ✅ Moved: table_2265.txt → train/
# ✅ Moved: table_2267.txt → train/
# ✅ Moved: table_2269.txt → train/
# ✅ Moved: table_227.txt → train/
# ✅ Moved: table_2270.txt → train/
# ✅ Moved: table_2274.txt → train/
# ✅ Moved: table_2275.txt → train/
# ✅ Moved: table_2276.txt → train/
# ✅ Moved: table_2277.txt → train/
# ✅ Moved: table_228.txt → train/
# ✅ Moved: table_2281.txt → train/
# ✅ Moved: table_2287.txt → train/
# ✅ Moved: table_2289.txt → train/
# ✅ Moved: table_229.txt → train/
# ✅ Moved: table_2290.txt → train/
# ✅ Moved: table_2291.txt → train/
# ✅ Moved: table_2294.txt → train/
# ✅ Moved: table_2295.txt → train/
# ✅ Moved: table_2296.txt → train/
# ✅ Moved: table_2298.txt → train/
# ✅ Moved: table_2300.txt → train/
# ✅ Moved: table_2301.txt → train/
# ✅ Moved: table_2305.txt → train/
# ✅ Moved: table_2307.txt → train/
# ✅ Moved: table_2312.txt → train/
# ✅ Moved: table_2313.txt → train/
# ✅ Moved: table_2314.txt → train/
# ✅ Moved: table_2317.txt → train/
# ✅ Moved: table_2319.txt → train/
# ✅ Moved: table_2324.txt → train/
# ✅ Moved: table_2326.txt → train/
# ✅ Moved: table_233.txt → train/
# ✅ Moved: table_2331.txt → train/
# ✅ Moved: table_2333.txt → train/
# ✅ Moved: table_2335.txt → train/
# ✅ Moved: table_2336.txt → train/
# ✅ Moved: table_2337.txt → train/
# ✅ Moved: table_2339.txt → train/
# ✅ Moved: table_2343.txt → train/
# ✅ Moved: table_2345.txt → train/
# ✅ Moved: table_2346.txt → train/
# ✅ Moved: table_2347.txt → train/
# ✅ Moved: table_2348.txt → train/
# ✅ Moved: table_2352.txt → train/
# ✅ Moved: table_2353.txt → train/
# ✅ Moved: table_2358.txt → train/
# ✅ Moved: table_2359.txt → train/
# ✅ Moved: table_236.txt → train/
# ✅ Moved: table_2360.txt → train/
# ✅ Moved: table_2361.txt → train/
# ✅ Moved: table_2363.txt → train/
# ✅ Moved: table_2365.txt → train/
# ✅ Moved: table_2366.txt → train/
# ✅ Moved: table_2367.txt → train/
# ✅ Moved: table_237.txt → train/
# ✅ Moved: table_2370.txt → train/
# ✅ Moved: table_2371.txt → train/
# ✅ Moved: table_2372.txt → train/
# ✅ Moved: table_2373.txt → train/
# ✅ Moved: table_2374.txt → train/
# ✅ Moved: table_2376.txt → train/
# ✅ Moved: table_238.txt → train/
# ✅ Moved: table_2381.txt → train/
# ✅ Moved: table_2383.txt → train/
# ✅ Moved: table_2384.txt → train/
# ✅ Moved: table_2385.txt → train/
# ✅ Moved: table_2387.txt → train/
# ✅ Moved: table_2394.txt → train/
# ✅ Moved: table_2399.txt → train/
# ✅ Moved: table_24.txt → train/
# ✅ Moved: table_2400.txt → train/
# ✅ Moved: table_2404.txt → train/
# ✅ Moved: table_2406.txt → train/
# ✅ Moved: table_2410.txt → train/
# ✅ Moved: table_2412.txt → train/
# ✅ Moved: table_2413.txt → train/
# ✅ Moved: table_2414.txt → train/
# ✅ Moved: table_2415.txt → train/
# ✅ Moved: table_2418.txt → train/
# ✅ Moved: table_2419.txt → train/
# ✅ Moved: table_2422.txt → train/
# ✅ Moved: table_2423.txt → train/
# ✅ Moved: table_2425.txt → train/
# ✅ Moved: table_2427.txt → train/
# ✅ Moved: table_2428.txt → train/
# ✅ Moved: table_2429.txt → train/
# ✅ Moved: table_2432.txt → train/
# ✅ Moved: table_2433.txt → train/
# ✅ Moved: table_2434.txt → train/
# ✅ Moved: table_2437.txt → train/
# ✅ Moved: table_2441.txt → train/
# ✅ Moved: table_2442.txt → train/
# ✅ Moved: table_2443.txt → train/
# ✅ Moved: table_2447.txt → train/
# ✅ Moved: table_2449.txt → train/
# ✅ Moved: table_245.txt → train/
# ✅ Moved: table_2455.txt → train/
# ✅ Moved: table_2459.txt → train/
# ✅ Moved: table_2460.txt → train/
# ✅ Moved: table_2461.txt → train/
# ✅ Moved: table_2464.txt → train/
# ✅ Moved: table_2465.txt → train/
# ✅ Moved: table_2472.txt → train/
# ✅ Moved: table_2473.txt → train/
# ✅ Moved: table_2475.txt → train/
# ✅ Moved: table_2476.txt → train/
# ✅ Moved: table_2478.txt → train/
# ✅ Moved: table_2480.txt → train/
# ✅ Moved: table_2486.txt → train/
# ✅ Moved: table_2487.txt → train/
# ✅ Moved: table_2488.txt → train/
# ✅ Moved: table_2491.txt → train/
# ✅ Moved: table_2492.txt → train/
# ✅ Moved: table_2494.txt → train/
# ✅ Moved: table_2495.txt → train/
# ✅ Moved: table_2496.txt → train/
# ✅ Moved: table_2497.txt → train/
# ✅ Moved: table_2499.txt → train/
# ✅ Moved: table_25.txt → train/
# ✅ Moved: table_250.txt → train/
# ✅ Moved: table_2500.txt → train/
# ✅ Moved: table_2504.txt → train/
# ✅ Moved: table_2506.txt → train/
# ✅ Moved: table_2512.txt → train/
# ✅ Moved: table_2518.txt → train/
# ✅ Moved: table_252.txt → train/
# ✅ Moved: table_2520.txt → train/
# ✅ Moved: table_2522.txt → train/
# ✅ Moved: table_2524.txt → train/
# ✅ Moved: table_2525.txt → train/
# ✅ Moved: table_2526.txt → train/
# ✅ Moved: table_2527.txt → train/
# ✅ Moved: table_2528.txt → train/
# ✅ Moved: table_2529.txt → train/
# ✅ Moved: table_253.txt → train/
# ✅ Moved: table_2535.txt → train/
# ✅ Moved: table_2539.txt → train/
# ✅ Moved: table_254.txt → train/
# ✅ Moved: table_2540.txt → train/
# ✅ Moved: table_2543.txt → train/
# ✅ Moved: table_2548.txt → train/
# ✅ Moved: table_255.txt → train/
# ✅ Moved: table_2551.txt → train/
# ✅ Moved: table_2557.txt → train/
# ✅ Moved: table_2559.txt → train/
# ✅ Moved: table_2560.txt → train/
# ✅ Moved: table_2562.txt → train/
# ✅ Moved: table_2563.txt → train/
# ✅ Moved: table_2565.txt → train/
# ✅ Moved: table_2569.txt → train/
# ✅ Moved: table_257.txt → train/
# ✅ Moved: table_2571.txt → train/
# ✅ Moved: table_2573.txt → train/
# ✅ Moved: table_2577.txt → train/
# ✅ Moved: table_2581.txt → train/
# ✅ Moved: table_2583.txt → train/
# ✅ Moved: table_2585.txt → train/
# ✅ Moved: table_2587.txt → train/
# ✅ Moved: table_259.txt → train/
# ✅ Moved: table_2592.txt → train/
# ✅ Moved: table_2598.txt → train/
# ✅ Moved: table_26.txt → train/
# ✅ Moved: table_2600.txt → train/
# ✅ Moved: table_2601.txt → train/
# ✅ Moved: table_2603.txt → train/
# ✅ Moved: table_2606.txt → train/
# ✅ Moved: table_2608.txt → train/
# ✅ Moved: table_2609.txt → train/
# ✅ Moved: table_2613.txt → train/
# ✅ Moved: table_2616.txt → train/
# ✅ Moved: table_2618.txt → train/
# ✅ Moved: table_2619.txt → train/
# ✅ Moved: table_2622.txt → train/
# ✅ Moved: table_2623.txt → train/
# ✅ Moved: table_2624.txt → train/
# ✅ Moved: table_2625.txt → train/
# ✅ Moved: table_2626.txt → train/
# ✅ Moved: table_2629.txt → train/
# ✅ Moved: table_2631.txt → train/
# ✅ Moved: table_2638.txt → train/
# ✅ Moved: table_2642.txt → train/
# ✅ Moved: table_2644.txt → train/
# ✅ Moved: table_2647.txt → train/
# ✅ Moved: table_2650.txt → train/
# ✅ Moved: table_2651.txt → train/
# ✅ Moved: table_2656.txt → train/
# ✅ Moved: table_2657.txt → train/
# ✅ Moved: table_2659.txt → train/
# ✅ Moved: table_266.txt → train/
# ✅ Moved: table_2660.txt → train/
# ✅ Moved: table_2661.txt → train/
# ✅ Moved: table_2662.txt → train/
# ✅ Moved: table_2663.txt → train/
# ✅ Moved: table_267.txt → train/
# ✅ Moved: table_2674.txt → train/
# ✅ Moved: table_2675.txt → train/
# ✅ Moved: table_2677.txt → train/
# ✅ Moved: table_2678.txt → train/
# ✅ Moved: table_2679.txt → train/
# ✅ Moved: table_2680.txt → train/
# ✅ Moved: table_2684.txt → train/
# ✅ Moved: table_2685.txt → train/
# ✅ Moved: table_2687.txt → train/
# ✅ Moved: table_2688.txt → train/
# ✅ Moved: table_2689.txt → train/
# ✅ Moved: table_2690.txt → train/
# ✅ Moved: table_2696.txt → train/
# ✅ Moved: table_2697.txt → train/
# ✅ Moved: table_2701.txt → train/
# ✅ Moved: table_2704.txt → train/
# ✅ Moved: table_2705.txt → train/
# ✅ Moved: table_2706.txt → train/
# ✅ Moved: table_2707.txt → train/
# ✅ Moved: table_271.txt → train/
# ✅ Moved: table_2711.txt → train/
# ✅ Moved: table_2712.txt → train/
# ✅ Moved: table_2713.txt → train/
# ✅ Moved: table_2714.txt → train/
# ✅ Moved: table_2721.txt → train/
# ✅ Moved: table_2723.txt → train/
# ✅ Moved: table_2726.txt → train/
# ✅ Moved: table_2732.txt → train/
# ✅ Moved: table_2733.txt → train/
# ✅ Moved: table_2735.txt → train/
# ✅ Moved: table_2738.txt → train/
# ✅ Moved: table_2744.txt → train/
# ✅ Moved: table_2747.txt → train/
# ✅ Moved: table_275.txt → train/
# ✅ Moved: table_2750.txt → train/
# ✅ Moved: table_2752.txt → train/
# ✅ Moved: table_2753.txt → train/
# ✅ Moved: table_2756.txt → train/
# ✅ Moved: table_2757.txt → train/
# ✅ Moved: table_2761.txt → train/
# ✅ Moved: table_2765.txt → train/
# ✅ Moved: table_2766.txt → train/
# ✅ Moved: table_2772.txt → train/
# ✅ Moved: table_2774.txt → train/
# ✅ Moved: table_2776.txt → train/
# ✅ Moved: table_2777.txt → train/
# ✅ Moved: table_2779.txt → train/
# ✅ Moved: table_278.txt → train/
# ✅ Moved: table_2780.txt → train/
# ✅ Moved: table_2788.txt → train/
# ✅ Moved: table_2789.txt → train/
# ✅ Moved: table_2791.txt → train/
# ✅ Moved: table_2793.txt → train/
# ✅ Moved: table_2794.txt → train/
# ✅ Moved: table_2801.txt → train/
# ✅ Moved: table_2809.txt → train/
# ✅ Moved: table_2810.txt → train/
# ✅ Moved: table_2813.txt → train/
# ✅ Moved: table_2816.txt → train/
# ✅ Moved: table_2817.txt → train/
# ✅ Moved: table_2819.txt → train/
# ✅ Moved: table_2821.txt → train/
# ✅ Moved: table_2825.txt → train/
# ✅ Moved: table_2830.txt → train/
# ✅ Moved: table_2833.txt → train/
# ✅ Moved: table_284.txt → train/
# ✅ Moved: table_2847.txt → train/
# ✅ Moved: table_2848.txt → train/
# ✅ Moved: table_2849.txt → train/
# ✅ Moved: table_285.txt → train/
# ✅ Moved: table_2851.txt → train/
# ✅ Moved: table_2853.txt → train/
# ✅ Moved: table_2855.txt → train/
# ✅ Moved: table_2857.txt → train/
# ✅ Moved: table_2858.txt → train/
# ✅ Moved: table_2864.txt → train/
# ✅ Moved: table_2865.txt → train/
# ✅ Moved: table_2866.txt → train/
# ✅ Moved: table_2869.txt → train/
# ✅ Moved: table_287.txt → train/
# ✅ Moved: table_2873.txt → train/
# ✅ Moved: table_2874.txt → train/
# ✅ Moved: table_2879.txt → train/
# ✅ Moved: table_2882.txt → train/
# ✅ Moved: table_2883.txt → train/
# ✅ Moved: table_2884.txt → train/
# ✅ Moved: table_2889.txt → train/
# ✅ Moved: table_2890.txt → train/
# ✅ Moved: table_2892.txt → train/
# ✅ Moved: table_2893.txt → train/
# ✅ Moved: table_2895.txt → train/
# ✅ Moved: table_2896.txt → train/
# ✅ Moved: table_290.txt → train/
# ✅ Moved: table_2903.txt → train/
# ✅ Moved: table_2905.txt → train/
# ✅ Moved: table_2908.txt → train/
# ✅ Moved: table_2910.txt → train/
# ✅ Moved: table_2911.txt → train/
# ✅ Moved: table_2912.txt → train/
# ✅ Moved: table_2913.txt → train/
# ✅ Moved: table_2914.txt → train/
# ✅ Moved: table_2917.txt → train/
# ✅ Moved: table_2921.txt → train/
# ✅ Moved: table_2922.txt → train/
# ✅ Moved: table_2924.txt → train/
# ✅ Moved: table_2928.txt → train/
# ✅ Moved: table_293.txt → train/
# ✅ Moved: table_2931.txt → train/
# ✅ Moved: table_2932.txt → train/
# ✅ Moved: table_2933.txt → train/
# ✅ Moved: table_2936.txt → train/
# ✅ Moved: table_2940.txt → train/
# ✅ Moved: table_2941.txt → train/
# ✅ Moved: table_2942.txt → train/
# ✅ Moved: table_2943.txt → train/
# ✅ Moved: table_2945.txt → train/
# ✅ Moved: table_2947.txt → train/
# ✅ Moved: table_295.txt → train/
# ✅ Moved: table_2950.txt → train/
# ✅ Moved: table_2951.txt → train/
# ✅ Moved: table_2952.txt → train/
# ✅ Moved: table_2954.txt → train/
# ✅ Moved: table_2955.txt → train/
# ✅ Moved: table_2958.txt → train/
# ✅ Moved: table_296.txt → train/
# ✅ Moved: table_2960.txt → train/
# ✅ Moved: table_2962.txt → train/
# ✅ Moved: table_2964.txt → train/
# ✅ Moved: table_2966.txt → train/
# ✅ Moved: table_2970.txt → train/
# ✅ Moved: table_2972.txt → train/
# ✅ Moved: table_2974.txt → train/
# ✅ Moved: table_2975.txt → train/
# ✅ Moved: table_2976.txt → train/
# ✅ Moved: table_2981.txt → train/
# ✅ Moved: table_2984.txt → train/
# ✅ Moved: table_2985.txt → train/
# ✅ Moved: table_2986.txt → train/
# ✅ Moved: table_2987.txt → train/
# ✅ Moved: table_2988.txt → train/
# ✅ Moved: table_2990.txt → train/
# ✅ Moved: table_2992.txt → train/
# ✅ Moved: table_2995.txt → train/
# ✅ Moved: table_2998.txt → train/
# ✅ Moved: table_30.txt → train/
# ✅ Moved: table_300.txt → train/
# ✅ Moved: table_3000.txt → train/
# ✅ Moved: table_3004.txt → train/
# ✅ Moved: table_3005.txt → train/
# ✅ Moved: table_3006.txt → train/
# ✅ Moved: table_301.txt → train/
# ✅ Moved: table_3012.txt → train/
# ✅ Moved: table_3019.txt → train/
# ✅ Moved: table_302.txt → train/
# ✅ Moved: table_3026.txt → train/
# ✅ Moved: table_3027.txt → train/
# ✅ Moved: table_3028.txt → train/
# ✅ Moved: table_3029.txt → train/
# ✅ Moved: table_3039.txt → train/
# ✅ Moved: table_304.txt → train/
# ✅ Moved: table_3040.txt → train/
# ✅ Moved: table_3041.txt → train/
# ✅ Moved: table_3042.txt → train/
# ✅ Moved: table_3044.txt → train/
# ✅ Moved: table_3046.txt → train/
# ✅ Moved: table_3047.txt → train/
# ✅ Moved: table_3048.txt → train/
# ✅ Moved: table_3053.txt → train/
# ✅ Moved: table_3057.txt → train/
# ✅ Moved: table_3059.txt → train/
# ✅ Moved: table_306.txt → train/
# ✅ Moved: table_3060.txt → train/
# ✅ Moved: table_3061.txt → train/
# ✅ Moved: table_3064.txt → train/
# ✅ Moved: table_3065.txt → train/
# ✅ Moved: table_3066.txt → train/
# ✅ Moved: table_3069.txt → train/
# ✅ Moved: table_3070.txt → train/
# ✅ Moved: table_3073.txt → train/
# ✅ Moved: table_3077.txt → train/
# ✅ Moved: table_3078.txt → train/
# ✅ Moved: table_308.txt → train/
# ✅ Moved: table_3080.txt → train/
# ✅ Moved: table_3082.txt → train/
# ✅ Moved: table_3083.txt → train/
# ✅ Moved: table_3085.txt → train/
# ✅ Moved: table_3087.txt → train/
# ✅ Moved: table_3090.txt → train/
# ✅ Moved: table_3091.txt → train/
# ✅ Moved: table_3092.txt → train/
# ✅ Moved: table_3095.txt → train/
# ✅ Moved: table_3096.txt → train/
# ✅ Moved: table_3098.txt → train/
# ✅ Moved: table_3099.txt → train/
# ✅ Moved: table_310.txt → train/
# ✅ Moved: table_3102.txt → train/
# ✅ Moved: table_3103.txt → train/
# ✅ Moved: table_3104.txt → train/
# ✅ Moved: table_3106.txt → train/
# ✅ Moved: table_311.txt → train/
# ✅ Moved: table_3111.txt → train/
# ✅ Moved: table_3120.txt → train/
# ✅ Moved: table_3123.txt → train/
# ✅ Moved: table_3124.txt → train/
# ✅ Moved: table_3128.txt → train/
# ✅ Moved: table_313.txt → train/
# ✅ Moved: table_3130.txt → train/
# ✅ Moved: table_3134.txt → train/
# ✅ Moved: table_3136.txt → train/
# ✅ Moved: table_3138.txt → train/
# ✅ Moved: table_3140.txt → train/
# ✅ Moved: table_3146.txt → train/
# ✅ Moved: table_3147.txt → train/
# ✅ Moved: table_3152.txt → train/
# ✅ Moved: table_3153.txt → train/
# ✅ Moved: table_3154.txt → train/
# ✅ Moved: table_3157.txt → train/
# ✅ Moved: table_3158.txt → train/
# ✅ Moved: table_3160.txt → train/
# ✅ Moved: table_3162.txt → train/
# ✅ Moved: table_3164.txt → train/
# ✅ Moved: table_3165.txt → train/
# ✅ Moved: table_3168.txt → train/
# ✅ Moved: table_3169.txt → train/
# ✅ Moved: table_3170.txt → train/
# ✅ Moved: table_3171.txt → train/
# ✅ Moved: table_3172.txt → train/
# ✅ Moved: table_3173.txt → train/
# ✅ Moved: table_3175.txt → train/
# ✅ Moved: table_3177.txt → train/
# ✅ Moved: table_3181.txt → train/
# ✅ Moved: table_3183.txt → train/
# ✅ Moved: table_3185.txt → train/
# ✅ Moved: table_3186.txt → train/
# ✅ Moved: table_3189.txt → train/
# ✅ Moved: table_319.txt → train/
# ✅ Moved: table_3190.txt → train/
# ✅ Moved: table_3193.txt → train/
# ✅ Moved: table_3194.txt → train/
# ✅ Moved: table_3196.txt → train/
# ✅ Moved: table_3198.txt → train/
# ✅ Moved: table_3199.txt → train/
# ✅ Moved: table_320.txt → train/
# ✅ Moved: table_3202.txt → train/
# ✅ Moved: table_3203.txt → train/
# ✅ Moved: table_3205.txt → train/
# ✅ Moved: table_3206.txt → train/
# ✅ Moved: table_3207.txt → train/
# ✅ Moved: table_3209.txt → train/
# ✅ Moved: table_321.txt → train/
# ✅ Moved: table_3210.txt → train/
# ✅ Moved: table_3211.txt → train/
# ✅ Moved: table_3213.txt → train/
# ✅ Moved: table_3214.txt → train/
# ✅ Moved: table_3215.txt → train/
# ✅ Moved: table_3216.txt → train/
# ✅ Moved: table_3218.txt → train/
# ✅ Moved: table_3225.txt → train/
# ✅ Moved: table_3228.txt → train/
# ✅ Moved: table_3229.txt → train/
# ✅ Moved: table_3230.txt → train/
# ✅ Moved: table_3231.txt → train/
# ✅ Moved: table_3233.txt → train/
# ✅ Moved: table_3234.txt → train/
# ✅ Moved: table_3237.txt → train/
# ✅ Moved: table_3238.txt → train/
# ✅ Moved: table_3239.txt → train/
# ✅ Moved: table_324.txt → train/
# ✅ Moved: table_3241.txt → train/
# ✅ Moved: table_3242.txt → train/
# ✅ Moved: table_3244.txt → train/
# ✅ Moved: table_3245.txt → train/
# ✅ Moved: table_3247.txt → train/
# ✅ Moved: table_3249.txt → train/
# ✅ Moved: table_3250.txt → train/
# ✅ Moved: table_3253.txt → train/
# ✅ Moved: table_3259.txt → train/
# ✅ Moved: table_3264.txt → train/
# ✅ Moved: table_3266.txt → train/
# ✅ Moved: table_3268.txt → train/
# ✅ Moved: table_327.txt → train/
# ✅ Moved: table_3271.txt → train/
# ✅ Moved: table_3272.txt → train/
# ✅ Moved: table_3277.txt → train/
# ✅ Moved: table_3278.txt → train/
# ✅ Moved: table_328.txt → train/
# ✅ Moved: table_3283.txt → train/
# ✅ Moved: table_3287.txt → train/
# ✅ Moved: table_3288.txt → train/
# ✅ Moved: table_3289.txt → train/
# ✅ Moved: table_3290.txt → train/
# ✅ Moved: table_3291.txt → train/
# ✅ Moved: table_3292.txt → train/
# ✅ Moved: table_3293.txt → train/
# ✅ Moved: table_3296.txt → train/
# ✅ Moved: table_3301.txt → train/
# ✅ Moved: table_3302.txt → train/
# ✅ Moved: table_3303.txt → train/
# ✅ Moved: table_3304.txt → train/
# ✅ Moved: table_3305.txt → train/
# ✅ Moved: table_3307.txt → train/
# ✅ Moved: table_3316.txt → train/
# ✅ Moved: table_3317.txt → train/
# ✅ Moved: table_3318.txt → train/
# ✅ Moved: table_3319.txt → train/
# ✅ Moved: table_3322.txt → train/
# ✅ Moved: table_3323.txt → train/
# ✅ Moved: table_3327.txt → train/
# ✅ Moved: table_3328.txt → train/
# ✅ Moved: table_3333.txt → train/
# ✅ Moved: table_3338.txt → train/
# ✅ Moved: table_3339.txt → train/
# ✅ Moved: table_334.txt → train/
# ✅ Moved: table_3341.txt → train/
# ✅ Moved: table_3342.txt → train/
# ✅ Moved: table_3343.txt → train/
# ✅ Moved: table_3344.txt → train/
# ✅ Moved: table_3345.txt → train/
# ✅ Moved: table_3347.txt → train/
# ✅ Moved: table_3348.txt → train/
# ✅ Moved: table_335.txt → train/
# ✅ Moved: table_3350.txt → train/
# ✅ Moved: table_3351.txt → train/
# ✅ Moved: table_3354.txt → train/
# ✅ Moved: table_3356.txt → train/
# ✅ Moved: table_3358.txt → train/
# ✅ Moved: table_3359.txt → train/
# ✅ Moved: table_3364.txt → train/
# ✅ Moved: table_3365.txt → train/
# ✅ Moved: table_3369.txt → train/
# ✅ Moved: table_3371.txt → train/
# ✅ Moved: table_3376.txt → train/
# ✅ Moved: table_3378.txt → train/
# ✅ Moved: table_3381.txt → train/
# ✅ Moved: table_3383.txt → train/
# ✅ Moved: table_3384.txt → train/
# ✅ Moved: table_3386.txt → train/
# ✅ Moved: table_3387.txt → train/
# ✅ Moved: table_3390.txt → train/
# ✅ Moved: table_3393.txt → train/
# ✅ Moved: table_3396.txt → train/
# ✅ Moved: table_3398.txt → train/
# ✅ Moved: table_34.txt → train/
# ✅ Moved: table_340.txt → train/
# ✅ Moved: table_3400.txt → train/
# ✅ Moved: table_3401.txt → train/
# ✅ Moved: table_3404.txt → train/
# ✅ Moved: table_3405.txt → train/
# ✅ Moved: table_3408.txt → train/
# ✅ Moved: table_3410.txt → train/
# ✅ Moved: table_3414.txt → train/
# ✅ Moved: table_3417.txt → train/
# ✅ Moved: table_3421.txt → train/
# ✅ Moved: table_3422.txt → train/
# ✅ Moved: table_3423.txt → train/
# ✅ Moved: table_3424.txt → train/
# ✅ Moved: table_3426.txt → train/
# ✅ Moved: table_3427.txt → train/
# ✅ Moved: table_3430.txt → train/
# ✅ Moved: table_3432.txt → train/
# ✅ Moved: table_3436.txt → train/
# ✅ Moved: table_3438.txt → train/
# ✅ Moved: table_3439.txt → train/
# ✅ Moved: table_344.txt → train/
# ✅ Moved: table_3440.txt → train/
# ✅ Moved: table_3443.txt → train/
# ✅ Moved: table_3446.txt → train/
# ✅ Moved: table_3450.txt → train/
# ✅ Moved: table_3451.txt → train/
# ✅ Moved: table_3452.txt → train/
# ✅ Moved: table_3455.txt → train/
# ✅ Moved: table_3456.txt → train/
# ✅ Moved: table_3457.txt → train/
# ✅ Moved: table_3458.txt → train/
# ✅ Moved: table_3461.txt → train/
# ✅ Moved: table_3463.txt → train/
# ✅ Moved: table_3468.txt → train/
# ✅ Moved: table_3469.txt → train/
# ✅ Moved: table_3470.txt → train/
# ✅ Moved: table_3473.txt → train/
# ✅ Moved: table_3474.txt → train/
# ✅ Moved: table_3478.txt → train/
# ✅ Moved: table_348.txt → train/
# ✅ Moved: table_3481.txt → train/
# ✅ Moved: table_3485.txt → train/
# ✅ Moved: table_3487.txt → train/
# ✅ Moved: table_3488.txt → train/
# ✅ Moved: table_349.txt → train/
# ✅ Moved: table_3497.txt → train/
# ✅ Moved: table_3498.txt → train/
# ✅ Moved: table_3499.txt → train/
# ✅ Moved: table_350.txt → train/
# ✅ Moved: table_3503.txt → train/
# ✅ Moved: table_351.txt → train/
# ✅ Moved: table_3511.txt → train/
# ✅ Moved: table_3512.txt → train/
# ✅ Moved: table_3515.txt → train/
# ✅ Moved: table_3516.txt → train/
# ✅ Moved: table_3520.txt → train/
# ✅ Moved: table_3521.txt → train/
# ✅ Moved: table_3522.txt → train/
# ✅ Moved: table_3527.txt → train/
# ✅ Moved: table_3528.txt → train/
# ✅ Moved: table_3531.txt → train/
# ✅ Moved: table_3536.txt → train/
# ✅ Moved: table_3539.txt → train/
# ✅ Moved: table_354.txt → train/
# ✅ Moved: table_3540.txt → train/
# ✅ Moved: table_355.txt → train/
# ✅ Moved: table_3550.txt → train/
# ✅ Moved: table_3552.txt → train/
# ✅ Moved: table_3553.txt → train/
# ✅ Moved: table_3557.txt → train/
# ✅ Moved: table_3558.txt → train/
# ✅ Moved: table_3562.txt → train/
# ✅ Moved: table_3563.txt → train/
# ✅ Moved: table_3564.txt → train/
# ✅ Moved: table_3566.txt → train/
# ✅ Moved: table_3567.txt → train/
# ✅ Moved: table_3568.txt → train/
# ✅ Moved: table_3570.txt → train/
# ✅ Moved: table_3574.txt → train/
# ✅ Moved: table_3580.txt → train/
# ✅ Moved: table_3583.txt → train/
# ✅ Moved: table_3588.txt → train/
# ✅ Moved: table_3589.txt → train/
# ✅ Moved: table_3591.txt → train/
# ✅ Moved: table_3597.txt → train/
# ✅ Moved: table_360.txt → train/
# ✅ Moved: table_3601.txt → train/
# ✅ Moved: table_3608.txt → train/
# ✅ Moved: table_3611.txt → train/
# ✅ Moved: table_3613.txt → train/
# ✅ Moved: table_3614.txt → train/
# ✅ Moved: table_3617.txt → train/
# ✅ Moved: table_3618.txt → train/
# ✅ Moved: table_362.txt → train/
# ✅ Moved: table_3620.txt → train/
# ✅ Moved: table_3621.txt → train/
# ✅ Moved: table_3622.txt → train/
# ✅ Moved: table_3624.txt → train/
# ✅ Moved: table_3628.txt → train/
# ✅ Moved: table_363.txt → train/
# ✅ Moved: table_3630.txt → train/
# ✅ Moved: table_3632.txt → train/
# ✅ Moved: table_3634.txt → train/
# ✅ Moved: table_3636.txt → train/
# ✅ Moved: table_3639.txt → train/
# ✅ Moved: table_364.txt → train/
# ✅ Moved: table_3644.txt → train/
# ✅ Moved: table_3645.txt → train/
# ✅ Moved: table_3648.txt → train/
# ✅ Moved: table_365.txt → train/
# ✅ Moved: table_3651.txt → train/
# ✅ Moved: table_3652.txt → train/
# ✅ Moved: table_3653.txt → train/
# ✅ Moved: table_3656.txt → train/
# ✅ Moved: table_3657.txt → train/
# ✅ Moved: table_3659.txt → train/
# ✅ Moved: table_366.txt → train/
# ✅ Moved: table_3662.txt → train/
# ✅ Moved: table_3663.txt → train/
# ✅ Moved: table_3665.txt → train/
# ✅ Moved: table_3666.txt → train/
# ✅ Moved: table_3667.txt → train/
# ✅ Moved: table_3670.txt → train/
# ✅ Moved: table_3671.txt → train/
# ✅ Moved: table_3677.txt → train/
# ✅ Moved: table_3678.txt → train/
# ✅ Moved: table_3680.txt → train/
# ✅ Moved: table_3681.txt → train/
# ✅ Moved: table_3684.txt → train/
# ✅ Moved: table_3686.txt → train/
# ✅ Moved: table_3689.txt → train/
# ✅ Moved: table_3690.txt → train/
# ✅ Moved: table_3692.txt → train/
# ✅ Moved: table_3695.txt → train/
# ✅ Moved: table_370.txt → train/
# ✅ Moved: table_3700.txt → train/
# ✅ Moved: table_3705.txt → train/
# ✅ Moved: table_3709.txt → train/
# ✅ Moved: table_371.txt → train/
# ✅ Moved: table_3714.txt → train/
# ✅ Moved: table_3718.txt → train/
# ✅ Moved: table_3719.txt → train/
# ✅ Moved: table_3720.txt → train/
# ✅ Moved: table_3725.txt → train/
# ✅ Moved: table_3726.txt → train/
# ✅ Moved: table_373.txt → train/
# ✅ Moved: table_3731.txt → train/
# ✅ Moved: table_3732.txt → train/
# ✅ Moved: table_3736.txt → train/
# ✅ Moved: table_3739.txt → train/
# ✅ Moved: table_374.txt → train/
# ✅ Moved: table_3740.txt → train/
# ✅ Moved: table_3742.txt → train/
# ✅ Moved: table_3743.txt → train/
# ✅ Moved: table_3748.txt → train/
# ✅ Moved: table_375.txt → train/
# ✅ Moved: table_3752.txt → train/
# ✅ Moved: table_3753.txt → train/
# ✅ Moved: table_3754.txt → train/
# ✅ Moved: table_3756.txt → train/
# ✅ Moved: table_3758.txt → train/
# ✅ Moved: table_376.txt → train/
# ✅ Moved: table_3761.txt → train/
# ✅ Moved: table_3762.txt → train/
# ✅ Moved: table_3763.txt → train/
# ✅ Moved: table_3768.txt → train/
# ✅ Moved: table_3769.txt → train/
# ✅ Moved: table_3771.txt → train/
# ✅ Moved: table_3772.txt → train/
# ✅ Moved: table_3778.txt → train/
# ✅ Moved: table_3780.txt → train/
# ✅ Moved: table_3781.txt → train/
# ✅ Moved: table_3785.txt → train/
# ✅ Moved: table_3787.txt → train/
# ✅ Moved: table_379.txt → train/
# ✅ Moved: table_3790.txt → train/
# ✅ Moved: table_3791.txt → train/
# ✅ Moved: table_3792.txt → train/
# ✅ Moved: table_3793.txt → train/
# ✅ Moved: table_3794.txt → train/
# ✅ Moved: table_3795.txt → train/
# ✅ Moved: table_3801.txt → train/
# ✅ Moved: table_3805.txt → train/
# ✅ Moved: table_3806.txt → train/
# ✅ Moved: table_381.txt → train/
# ✅ Moved: table_3810.txt → train/
# ✅ Moved: table_3815.txt → train/
# ✅ Moved: table_3817.txt → train/
# ✅ Moved: table_3818.txt → train/
# ✅ Moved: table_3820.txt → train/
# ✅ Moved: table_3822.txt → train/
# ✅ Moved: table_3823.txt → train/
# ✅ Moved: table_3824.txt → train/
# ✅ Moved: table_3826.txt → train/
# ✅ Moved: table_3827.txt → train/
# ✅ Moved: table_383.txt → train/
# ✅ Moved: table_3831.txt → train/
# ✅ Moved: table_3832.txt → train/
# ✅ Moved: table_3835.txt → train/
# ✅ Moved: table_3837.txt → train/
# ✅ Moved: table_3838.txt → train/
# ✅ Moved: table_3839.txt → train/
# ✅ Moved: table_3840.txt → train/
# ✅ Moved: table_3841.txt → train/
# ✅ Moved: table_3842.txt → train/
# ✅ Moved: table_3844.txt → train/
# ✅ Moved: table_3845.txt → train/
# ✅ Moved: table_3848.txt → train/
# ✅ Moved: table_385.txt → train/
# ✅ Moved: table_3851.txt → train/
# ✅ Moved: table_3854.txt → train/
# ✅ Moved: table_3858.txt → train/
# ✅ Moved: table_3860.txt → train/
# ✅ Moved: table_3868.txt → train/
# ✅ Moved: table_387.txt → train/
# ✅ Moved: table_3871.txt → train/
# ✅ Moved: table_3874.txt → train/
# ✅ Moved: table_3876.txt → train/
# ✅ Moved: table_3878.txt → train/
# ✅ Moved: table_3879.txt → train/
# ✅ Moved: table_3881.txt → train/
# ✅ Moved: table_3883.txt → train/
# ✅ Moved: table_3884.txt → train/
# ✅ Moved: table_3885.txt → train/
# ✅ Moved: table_3886.txt → train/
# ✅ Moved: table_3887.txt → train/
# ✅ Moved: table_3888.txt → train/
# ✅ Moved: table_389.txt → train/
# ✅ Moved: table_3892.txt → train/
# ✅ Moved: table_3894.txt → train/
# ✅ Moved: table_3895.txt → train/
# ✅ Moved: table_3899.txt → train/
# ✅ Moved: table_3900.txt → train/
# ✅ Moved: table_3901.txt → train/
# ✅ Moved: table_3903.txt → train/
# ✅ Moved: table_3904.txt → train/
# ✅ Moved: table_3905.txt → train/
# ✅ Moved: table_3906.txt → train/
# ✅ Moved: table_3908.txt → train/
# ✅ Moved: table_391.txt → train/
# ✅ Moved: table_3910.txt → train/
# ✅ Moved: table_3913.txt → train/
# ✅ Moved: table_3915.txt → train/
# ✅ Moved: table_3916.txt → train/
# ✅ Moved: table_3919.txt → train/
# ✅ Moved: table_392.txt → train/
# ✅ Moved: table_3923.txt → train/
# ✅ Moved: table_3924.txt → train/
# ✅ Moved: table_3925.txt → train/
# ✅ Moved: table_3927.txt → train/
# ✅ Moved: table_3930.txt → train/
# ✅ Moved: table_3933.txt → train/
# ✅ Moved: table_3936.txt → train/
# ✅ Moved: table_3938.txt → train/
# ✅ Moved: table_3944.txt → train/
# ✅ Moved: table_3946.txt → train/
# ✅ Moved: table_3947.txt → train/
# ✅ Moved: table_3948.txt → train/
# ✅ Moved: table_3950.txt → train/
# ✅ Moved: table_3952.txt → train/
# ✅ Moved: table_3953.txt → train/
# ✅ Moved: table_3959.txt → train/
# ✅ Moved: table_396.txt → train/
# ✅ Moved: table_3962.txt → train/
# ✅ Moved: table_3963.txt → train/
# ✅ Moved: table_3965.txt → train/
# ✅ Moved: table_3966.txt → train/
# ✅ Moved: table_3967.txt → train/
# ✅ Moved: table_3969.txt → train/
# ✅ Moved: table_3974.txt → train/
# ✅ Moved: table_3976.txt → train/
# ✅ Moved: table_3977.txt → train/
# ✅ Moved: table_3984.txt → train/
# ✅ Moved: table_3985.txt → train/
# ✅ Moved: table_3986.txt → train/
# ✅ Moved: table_3993.txt → train/
# ✅ Moved: table_3994.txt → train/
# ✅ Moved: table_3995.txt → train/
# ✅ Moved: table_3996.txt → train/
# ✅ Moved: table_40.txt → train/
# ✅ Moved: table_4000.txt → train/
# ✅ Moved: table_4008.txt → train/
# ✅ Moved: table_4011.txt → train/
# ✅ Moved: table_4014.txt → train/
# ✅ Moved: table_4015.txt → train/
# ✅ Moved: table_4019.txt → train/
# ✅ Moved: table_4020.txt → train/
# ✅ Moved: table_4021.txt → train/
# ✅ Moved: table_4023.txt → train/
# ✅ Moved: table_4024.txt → train/
# ✅ Moved: table_4026.txt → train/
# ✅ Moved: table_4027.txt → train/
# ✅ Moved: table_4028.txt → train/
# ✅ Moved: table_403.txt → train/
# ✅ Moved: table_4030.txt → train/
# ✅ Moved: table_4031.txt → train/
# ✅ Moved: table_4032.txt → train/
# ✅ Moved: table_4033.txt → train/
# ✅ Moved: table_4035.txt → train/
# ✅ Moved: table_4036.txt → train/
# ✅ Moved: table_4038.txt → train/
# ✅ Moved: table_404.txt → train/
# ✅ Moved: table_4040.txt → train/
# ✅ Moved: table_4042.txt → train/
# ✅ Moved: table_4043.txt → train/
# ✅ Moved: table_4048.txt → train/
# ✅ Moved: table_4049.txt → train/
# ✅ Moved: table_4051.txt → train/
# ✅ Moved: table_4052.txt → train/
# ✅ Moved: table_4053.txt → train/
# ✅ Moved: table_4054.txt → train/
# ✅ Moved: table_4055.txt → train/
# ✅ Moved: table_406.txt → train/
# ✅ Moved: table_4060.txt → train/
# ✅ Moved: table_4066.txt → train/
# ✅ Moved: table_4067.txt → train/
# ✅ Moved: table_4069.txt → train/
# ✅ Moved: table_407.txt → train/
# ✅ Moved: table_4070.txt → train/
# ✅ Moved: table_4073.txt → train/
# ...
# ✅ Moved: table_1510.txt → test/
# ✅ Moved: table_1561.txt → test/
# ✅ Moved: table_1571.txt → test/
# ✅ Moved: table_1575.txt → test/
# ✅ Moved: table_1576.txt → test/
# ✅ Moved: table_1585.txt → test/
# ✅ Moved: table_16.txt → test/
# ✅ Moved: table_1618.txt → test/
# ✅ Moved: table_1622.txt → test/
# ✅ Moved: table_1668.txt → test/
# ✅ Moved: table_1697.txt → test/
# ✅ Moved: table_1751.txt → test/
# ✅ Moved: table_1758.txt → test/
# ✅ Moved: table_1776.txt → test/
# ✅ Moved: table_1785.txt → test/
# ✅ Moved: table_1844.txt → test/
# ✅ Moved: table_1849.txt → test/
# ✅ Moved: table_1857.txt → test/
# ✅ Moved: table_186.txt → test/
# ✅ Moved: table_1888.txt → test/
# ✅ Moved: table_1910.txt → test/
# ✅ Moved: table_1943.txt → test/
# ✅ Moved: table_1949.txt → test/
# ✅ Moved: table_1954.txt → test/
# ✅ Moved: table_1975.txt → test/
# ✅ Moved: table_1994.txt → test/
# ✅ Moved: table_2006.txt → test/
# ✅ Moved: table_2061.txt → test/
# ✅ Moved: table_2088.txt → test/
# ✅ Moved: table_2090.txt → test/
# ✅ Moved: table_21.txt → test/
# ✅ Moved: table_2137.txt → test/
# ✅ Moved: table_2143.txt → test/
# ✅ Moved: table_2144.txt → test/
# ✅ Moved: table_2184.txt → test/
# ✅ Moved: table_2202.txt → test/
# ✅ Moved: table_2227.txt → test/
# ✅ Moved: table_2237.txt → test/
# ✅ Moved: table_2249.txt → test/
# ✅ Moved: table_2264.txt → test/
# ✅ Moved: table_2282.txt → test/
# ✅ Moved: table_2293.txt → test/
# ✅ Moved: table_2299.txt → test/
# ✅ Moved: table_2316.txt → test/
# ✅ Moved: table_2322.txt → test/
# ✅ Moved: table_2362.txt → test/
# ✅ Moved: table_2379.txt → test/
# ✅ Moved: table_240.txt → test/
# ✅ Moved: table_2453.txt → test/
# ✅ Moved: table_2470.txt → test/
# ✅ Moved: table_2503.txt → test/
# ✅ Moved: table_251.txt → test/
# ✅ Moved: table_2530.txt → test/
# ✅ Moved: table_2532.txt → test/
# ✅ Moved: table_2538.txt → test/
# ✅ Moved: table_2575.txt → test/
# ✅ Moved: table_2582.txt → test/
# ✅ Moved: table_2610.txt → test/
# ✅ Moved: table_2639.txt → test/
# ✅ Moved: table_264.txt → test/
# ✅ Moved: table_2640.txt → test/
# ✅ Moved: table_2648.txt → test/
# ✅ Moved: table_2655.txt → test/
# ✅ Moved: table_269.txt → test/
# ✅ Moved: table_2720.txt → test/
# ✅ Moved: table_2727.txt → test/
# ✅ Moved: table_2741.txt → test/
# ✅ Moved: table_276.txt → test/
# ✅ Moved: table_2764.txt → test/
# ✅ Moved: table_2796.txt → test/
# ✅ Moved: table_2803.txt → test/
# ✅ Moved: table_281.txt → test/
# ✅ Moved: table_2811.txt → test/
# ✅ Moved: table_2820.txt → test/
# ✅ Moved: table_2831.txt → test/
# ✅ Moved: table_2844.txt → test/
# ✅ Moved: table_2870.txt → test/
# ✅ Moved: table_2880.txt → test/
# ✅ Moved: table_29.txt → test/
# ✅ Moved: table_2919.txt → test/
# ✅ Moved: table_292.txt → test/
# ✅ Moved: table_2920.txt → test/
# ✅ Moved: table_2953.txt → test/
# ✅ Moved: table_2957.txt → test/
# ✅ Moved: table_2965.txt → test/
# ✅ Moved: table_2969.txt → test/
# ✅ Moved: table_298.txt → test/
# ✅ Moved: table_2982.txt → test/
# ✅ Moved: table_299.txt → test/
# ✅ Moved: table_3016.txt → test/
# ✅ Moved: table_3017.txt → test/
# ✅ Moved: table_3021.txt → test/
# ✅ Moved: table_3023.txt → test/
# ✅ Moved: table_3068.txt → test/
# ✅ Moved: table_3071.txt → test/
# ✅ Moved: table_3084.txt → test/
# ✅ Moved: table_309.txt → test/
# ✅ Moved: table_3110.txt → test/
# ✅ Moved: table_3132.txt → test/
# ✅ Moved: table_3135.txt → test/
# ✅ Moved: table_3142.txt → test/
# ✅ Moved: table_3143.txt → test/
# ✅ Moved: table_3148.txt → test/
# ✅ Moved: table_3163.txt → test/
# ✅ Moved: table_3174.txt → test/
# ✅ Moved: table_3188.txt → test/
# ✅ Moved: table_3192.txt → test/
# ✅ Moved: table_3252.txt → test/
# ✅ Moved: table_3298.txt → test/
# ✅ Moved: table_3314.txt → test/
# ✅ Moved: table_332.txt → test/
# ✅ Moved: table_3324.txt → test/
# ✅ Moved: table_3331.txt → test/
# ✅ Moved: table_3334.txt → test/
# ✅ Moved: table_3361.txt → test/
# ✅ Moved: table_3366.txt → test/
# ✅ Moved: table_3394.txt → test/
# ✅ Moved: table_3402.txt → test/
# ✅ Moved: table_3403.txt → test/
# ✅ Moved: table_3411.txt → test/
# ✅ Moved: table_3429.txt → test/
# ✅ Moved: table_3437.txt → test/
# ✅ Moved: table_345.txt → test/
# ✅ Moved: table_3454.txt → test/
# ✅ Moved: table_3464.txt → test/
# ✅ Moved: table_3472.txt → test/
# ✅ Moved: table_3484.txt → test/
# ✅ Moved: table_3510.txt → test/
# ✅ Moved: table_353.txt → test/
# ✅ Moved: table_3556.txt → test/
# ✅ Moved: table_3573.txt → test/
# ✅ Moved: table_359.txt → test/
# ✅ Moved: table_3592.txt → test/
# ✅ Moved: table_3600.txt → test/
# ✅ Moved: table_3649.txt → test/
# ✅ Moved: table_37.txt → test/
# ✅ Moved: table_3722.txt → test/
# ✅ Moved: table_3733.txt → test/
# ✅ Moved: table_3746.txt → test/
# ✅ Moved: table_3773.txt → test/
# ✅ Moved: table_3775.txt → test/
# ✅ Moved: table_3796.txt → test/
# ✅ Moved: table_38.txt → test/
# ✅ Moved: table_3808.txt → test/
# ✅ Moved: table_3846.txt → test/
# ✅ Moved: table_3862.txt → test/
# ✅ Moved: table_3897.txt → test/
# ✅ Moved: table_3909.txt → test/
# ✅ Moved: table_3920.txt → test/
# ✅ Moved: table_3921.txt → test/
# ✅ Moved: table_3937.txt → test/
# ✅ Moved: table_3945.txt → test/
# ✅ Moved: table_3968.txt → test/
# ✅ Moved: table_3979.txt → test/
# ✅ Moved: table_3980.txt → test/
# ✅ Moved: table_3987.txt → test/
# ✅ Moved: table_4010.txt → test/
# ✅ Moved: table_4013.txt → test/
# ✅ Moved: table_4047.txt → test/
# ✅ Moved: table_4056.txt → test/
# ✅ Moved: table_4062.txt → test/
# ✅ Moved: table_4080.txt → test/
# ✅ Moved: table_4087.txt → test/
# ✅ Moved: table_4088.txt → test/
# ✅ Moved: table_410.txt → test/
# ✅ Moved: table_4101.txt → test/
# ✅ Moved: table_4116.txt → test/
# ✅ Moved: table_4167.txt → test/
# ✅ Moved: table_4170.txt → test/
# ✅ Moved: table_4182.txt → test/
# ✅ Moved: table_4192.txt → test/
# ✅ Moved: table_4196.txt → test/
# ✅ Moved: table_4201.txt → test/
# ✅ Moved: table_4209.txt → test/
# ✅ Moved: table_4239.txt → test/
# ✅ Moved: table_425.txt → test/
# ✅ Moved: table_4263.txt → test/
# ✅ Moved: table_4265.txt → test/
# ✅ Moved: table_4297.txt → test/
# ✅ Moved: table_4301.txt → test/
# ✅ Moved: table_4318.txt → test/
# ✅ Moved: table_4358.txt → test/
# ✅ Moved: table_4371.txt → test/
# ✅ Moved: table_4385.txt → test/
# ✅ Moved: table_4494.txt → test/
# ✅ Moved: table_4511.txt → test/
# ✅ Moved: table_4517.txt → test/
# ✅ Moved: table_452.txt → test/
# ✅ Moved: table_4527.txt → test/
# ✅ Moved: table_4532.txt → test/
# ✅ Moved: table_4535.txt → test/
# ✅ Moved: table_4545.txt → test/
# ✅ Moved: table_4570.txt → test/
# ✅ Moved: table_4574.txt → test/
# ✅ Moved: table_4577.txt → test/
# ✅ Moved: table_4606.txt → test/
# ✅ Moved: table_4629.txt → test/
# ✅ Moved: table_468.txt → test/
# ✅ Moved: table_469.txt → test/
# ✅ Moved: table_4700.txt → test/
# ✅ Moved: table_4709.txt → test/
# ✅ Moved: table_4718.txt → test/
# ✅ Moved: table_4748.txt → test/
# ✅ Moved: table_4765.txt → test/
# ✅ Moved: table_4774.txt → test/
# ✅ Moved: table_4784.txt → test/
# ✅ Moved: table_4794.txt → test/
# ✅ Moved: table_480.txt → test/
# ✅ Moved: table_4805.txt → test/
# ✅ Moved: table_4853.txt → test/
# ✅ Moved: table_4865.txt → test/
# ✅ Moved: table_4900.txt → test/
# ✅ Moved: table_4905.txt → test/
# ✅ Moved: table_4916.txt → test/
# ✅ Moved: table_492.txt → test/
# ✅ Moved: table_4956.txt → test/
# ✅ Moved: table_4960.txt → test/
# ✅ Moved: table_4964.txt → test/
# ✅ Moved: table_4980.txt → test/
# ✅ Moved: table_5005.txt → test/
# ✅ Moved: table_5012.txt → test/
# ✅ Moved: table_5063.txt → test/
# ✅ Moved: table_5083.txt → test/
# ✅ Moved: table_5125.txt → test/
# ✅ Moved: table_5131.txt → test/
# ✅ Moved: table_5135.txt → test/
# ✅ Moved: table_5151.txt → test/
# ✅ Moved: table_5183.txt → test/
# ✅ Moved: table_5194.txt → test/
# ✅ Moved: table_5208.txt → test/
# ✅ Moved: table_524.txt → test/
# ✅ Moved: table_5257.txt → test/
# ✅ Moved: table_5281.txt → test/
# ✅ Moved: table_5306.txt → test/
# ✅ Moved: table_5342.txt → test/
# ✅ Moved: table_5346.txt → test/
# ✅ Moved: table_5379.txt → test/
# ✅ Moved: table_5408.txt → test/
# ✅ Moved: table_5418.txt → test/
# ✅ Moved: table_5448.txt → test/
# ✅ Moved: table_5472.txt → test/
# ✅ Moved: table_5481.txt → test/
# ✅ Moved: table_5500.txt → test/
# ✅ Moved: table_5523.txt → test/
# ✅ Moved: table_5554.txt → test/
# ✅ Moved: table_5557.txt → test/
# ✅ Moved: table_5583.txt → test/
# ✅ Moved: table_5616.txt → test/
# ✅ Moved: table_5647.txt → test/
# ✅ Moved: table_5667.txt → test/
# ✅ Moved: table_5673.txt → test/
# ✅ Moved: table_5684.txt → test/
# ✅ Moved: table_5707.txt → test/
# ✅ Moved: table_5739.txt → test/
# ✅ Moved: table_5755.txt → test/
# ✅ Moved: table_5779.txt → test/
# ✅ Moved: table_5842.txt → test/
# ✅ Moved: table_589.txt → test/
# ✅ Moved: table_5942.txt → test/
# ✅ Moved: table_5950.txt → test/
# ✅ Moved: table_5957.txt → test/
# ✅ Moved: table_5967.txt → test/
# ✅ Moved: table_5980.txt → test/
# ✅ Moved: table_5986.txt → test/
# ✅ Moved: table_5994.txt → test/
# ✅ Moved: table_5998.txt → test/
# ✅ Moved: table_6009.txt → test/
# ✅ Moved: table_6040.txt → test/
# ✅ Moved: table_6047.txt → test/
# ✅ Moved: table_6076.txt → test/
# ✅ Moved: table_6116.txt → test/
# ✅ Moved: table_6146.txt → test/
# ✅ Moved: table_6185.txt → test/
# ✅ Moved: table_6198.txt → test/
# ✅ Moved: table_6201.txt → test/
# ✅ Moved: table_6230.txt → test/
# ✅ Moved: table_6249.txt → test/
# ✅ Moved: table_6275.txt → test/
# ✅ Moved: table_6305.txt → test/
# ✅ Moved: table_6307.txt → test/
# ✅ Moved: table_6316.txt → test/
# ✅ Moved: table_6326.txt → test/
# ✅ Moved: table_6411.txt → test/
# ✅ Moved: table_6425.txt → test/
# ✅ Moved: table_6437.txt → test/
# ✅ Moved: table_6467.txt → test/
# ✅ Moved: table_652.txt → test/
# ✅ Moved: table_6532.txt → test/
# ✅ Moved: table_6534.txt → test/
# ✅ Moved: table_6547.txt → test/
# ✅ Moved: table_6572.txt → test/
# ✅ Moved: table_6595.txt → test/
# ✅ Moved: table_6607.txt → test/
# ✅ Moved: table_6618.txt → test/
# ✅ Moved: table_6619.txt → test/
# ✅ Moved: table_6624.txt → test/
# ✅ Moved: table_6627.txt → test/
# ✅ Moved: table_6628.txt → test/
# ✅ Moved: table_6638.txt → test/
# ✅ Moved: table_6643.txt → test/
# ✅ Moved: table_6648.txt → test/
# ✅ Moved: table_667.txt → test/
# ✅ Moved: table_6672.txt → test/
# ✅ Moved: table_6714.txt → test/
# ✅ Moved: table_6725.txt → test/
# ✅ Moved: table_6734.txt → test/
# ✅ Moved: table_6750.txt → test/
# ✅ Moved: table_6799.txt → test/
# ✅ Moved: table_6805.txt → test/
# ✅ Moved: table_6815.txt → test/
# ✅ Moved: table_6845.txt → test/
# ✅ Moved: table_6855.txt → test/
# ✅ Moved: table_6864.txt → test/
# ✅ Moved: table_6867.txt → test/
# ✅ Moved: table_6870.txt → test/
# ✅ Moved: table_6891.txt → test/
# ✅ Moved: table_6894.txt → test/
# ✅ Moved: table_6905.txt → test/
# ✅ Moved: table_6906.txt → test/
# ✅ Moved: table_6936.txt → test/
# ✅ Moved: table_6945.txt → test/
# ✅ Moved: table_70.txt → test/
# ✅ Moved: table_7003.txt → test/
# ✅ Moved: table_7020.txt → test/
# ✅ Moved: table_7054.txt → test/
# ✅ Moved: table_7104.txt → test/
# ✅ Moved: table_7106.txt → test/
# ✅ Moved: table_7114.txt → test/
# ✅ Moved: table_7122.txt → test/
# ✅ Moved: table_7127.txt → test/
# ✅ Moved: table_713.txt → test/
# ✅ Moved: table_7134.txt → test/
# ✅ Moved: table_7150.txt → test/
# ✅ Moved: table_7157.txt → test/
# ✅ Moved: table_7178.txt → test/
# ✅ Moved: table_7184.txt → test/
# ✅ Moved: table_7187.txt → test/
# ✅ Moved: table_7196.txt → test/
# ✅ Moved: table_7204.txt → test/
# ✅ Moved: table_7213.txt → test/
# ✅ Moved: table_7231.txt → test/
# ✅ Moved: table_7249.txt → test/
# ✅ Moved: table_7261.txt → test/
# ✅ Moved: table_7270.txt → test/
# ✅ Moved: table_7286.txt → test/
# ✅ Moved: table_7311.txt → test/
# ✅ Moved: table_7345.txt → test/
# ✅ Moved: table_7352.txt → test/
# ✅ Moved: table_7355.txt → test/
# ✅ Moved: table_7380.txt → test/
# ✅ Moved: table_7392.txt → test/
# ✅ Moved: table_7407.txt → test/
# ✅ Moved: table_7409.txt → test/
# ✅ Moved: table_7459.txt → test/
# ✅ Moved: table_746.txt → test/
# ✅ Moved: table_7469.txt → test/
# ✅ Moved: table_748.txt → test/
# ✅ Moved: table_7513.txt → test/
# ✅ Moved: table_7514.txt → test/
# ✅ Moved: table_7516.txt → test/
# ✅ Moved: table_7540.txt → test/
# ✅ Moved: table_7571.txt → test/
# ✅ Moved: table_7596.txt → test/
# ✅ Moved: table_7600.txt → test/
# ✅ Moved: table_7604.txt → test/
# ✅ Moved: table_7620.txt → test/
# ✅ Moved: table_7639.txt → test/
# ✅ Moved: table_7645.txt → test/
# ✅ Moved: table_7649.txt → test/
# ✅ Moved: table_7658.txt → test/
# ✅ Moved: table_766.txt → test/
# ✅ Moved: table_7660.txt → test/
# ✅ Moved: table_7679.txt → test/
# ✅ Moved: table_7687.txt → test/
# ✅ Moved: table_7688.txt → test/
# ✅ Moved: table_769.txt → test/
# ✅ Moved: table_776.txt → test/
# ✅ Moved: table_7799.txt → test/
# ✅ Moved: table_7822.txt → test/
# ✅ Moved: table_7825.txt → test/
# ✅ Moved: table_7840.txt → test/
# ✅ Moved: table_7843.txt → test/
# ✅ Moved: table_7856.txt → test/
# ✅ Moved: table_7885.txt → test/
# ✅ Moved: table_7893.txt → test/
# ✅ Moved: table_7919.txt → test/
# ✅ Moved: table_798.txt → test/
# ✅ Moved: table_8001.txt → test/
# ✅ Moved: table_8015.txt → test/
# ✅ Moved: table_8018.txt → test/
# ✅ Moved: table_8067.txt → test/
# ✅ Moved: table_8087.txt → test/
# ✅ Moved: table_8095.txt → test/
# ✅ Moved: table_812.txt → test/
# ✅ Moved: table_8128.txt → test/
# ✅ Moved: table_8144.txt → test/
# ✅ Moved: table_8162.txt → test/
# ✅ Moved: table_8181.txt → test/
# ✅ Moved: table_8189.txt → test/
# ✅ Moved: table_8196.txt → test/
# ✅ Moved: table_8220.txt → test/
# ✅ Moved: table_8222.txt → test/
# ✅ Moved: table_8223.txt → test/
# ✅ Moved: table_824.txt → test/
# ✅ Moved: table_8266.txt → test/
# ✅ Moved: table_828.txt → test/
# ✅ Moved: table_8301.txt → test/
# ✅ Moved: table_8309.txt → test/
# ✅ Moved: table_832.txt → test/
# ✅ Moved: table_8321.txt → test/
# ✅ Moved: table_8322.txt → test/
# ✅ Moved: table_8335.txt → test/
# ✅ Moved: table_8367.txt → test/
# ✅ Moved: table_8371.txt → test/
# ✅ Moved: table_8417.txt → test/
# ✅ Moved: table_8418.txt → test/
# ✅ Moved: table_8441.txt → test/
# ✅ Moved: table_8464.txt → test/
# ✅ Moved: table_8474.txt → test/
# ✅ Moved: table_851.txt → test/
# ✅ Moved: table_8519.txt → test/
# ✅ Moved: table_8567.txt → test/
# ✅ Moved: table_8594.txt → test/
# ✅ Moved: table_8622.txt → test/
# ✅ Moved: table_8670.txt → test/
# ✅ Moved: table_8695.txt → test/
# ✅ Moved: table_8714.txt → test/
# ✅ Moved: table_8727.txt → test/
# ✅ Moved: table_8737.txt → test/
# ✅ Moved: table_875.txt → test/
# ✅ Moved: table_878.txt → test/
# ✅ Moved: table_8790.txt → test/
# ✅ Moved: table_8811.txt → test/
# ✅ Moved: table_8817.txt → test/
# ✅ Moved: table_8831.txt → test/
# ✅ Moved: table_8843.txt → test/
# ✅ Moved: table_8923.txt → test/
# ✅ Moved: table_8991.txt → test/
# ✅ Moved: table_9066.txt → test/
# ✅ Moved: table_9077.txt → test/
# ✅ Moved: table_9079.txt → test/
# ✅ Moved: table_909.txt → test/
# ✅ Moved: table_913.txt → test/
# ✅ Moved: table_9137.txt → test/
# ✅ Moved: table_9153.txt → test/
# ✅ Moved: table_9160.txt → test/
# ✅ Moved: table_9171.txt → test/
# ✅ Moved: table_9250.txt → test/
# ✅ Moved: table_9258.txt → test/
# ✅ Moved: table_9260.txt → test/
# ✅ Moved: table_9279.txt → test/
# ✅ Moved: table_9291.txt → test/
# ✅ Moved: table_9303.txt → test/
# ✅ Moved: table_9304.txt → test/
# ✅ Moved: table_9308.txt → test/
# ✅ Moved: table_9328.txt → test/
# ✅ Moved: table_9333.txt → test/
# ✅ Moved: table_9352.txt → test/
# ✅ Moved: table_936.txt → test/
# ✅ Moved: table_9397.txt → test/
# ✅ Moved: table_9407.txt → test/
# ✅ Moved: table_9421.txt → test/
# ✅ Moved: table_9441.txt → test/
# ✅ Moved: table_9442.txt → test/
# ✅ Moved: table_9454.txt → test/
# ✅ Moved: table_9473.txt → test/
# ✅ Moved: table_9474.txt → test/
# ✅ Moved: table_9475.txt → test/
# ✅ Moved: table_9483.txt → test/
# ✅ Moved: table_9486.txt → test/
# ✅ Moved: table_9493.txt → test/
# ✅ Moved: table_9524.txt → test/
# ✅ Moved: table_954.txt → test/
# ✅ Moved: table_9544.txt → test/
# ✅ Moved: table_9545.txt → test/
# ✅ Moved: table_9560.txt → test/
# ✅ Moved: table_9562.txt → test/
# ✅ Moved: table_9568.txt → test/
# ✅ Moved: table_9580.txt → test/
# ✅ Moved: table_9602.txt → test/
# ✅ Moved: table_9616.txt → test/
# ✅ Moved: table_9678.txt → test/
# ✅ Moved: table_972.txt → test/
# ✅ Moved: table_9747.txt → test/
# ✅ Moved: table_9772.txt → test/
# ✅ Moved: table_9773.txt → test/
# ✅ Moved: table_9781.txt → test/
# ✅ Moved: table_9782.txt → test/
# ✅ Moved: table_9786.txt → test/
# ✅ Moved: table_98.txt → test/
# ✅ Moved: table_982.txt → test/
# ✅ Moved: table_9820.txt → test/
# ✅ Moved: table_9855.txt → test/
# ✅ Moved: table_9865.txt → test/
# ✅ Moved: table_9867.txt → test/
# ✅ Moved: table_9919.txt → test/
# ✅ Moved: table_9952.txt → test/
# ✅ Moved: table_9978.txt → test/
# ✅ Moved: table_9980.txt → test/
# ✅ Moved: table_9992.txt → test/
# ✅ Moved: table_9994.txt → test/
